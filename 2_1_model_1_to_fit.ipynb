# %%
import os 
import json
import pickle
from datetime import datetime
from copy import deepcopy

import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dropout, Bidirectional, Attention, Concatenate, Dense
from keras.callbacks import ModelCheckpoint

from konlpy.tag import Okt

from sklearn.model_selection import train_test_split

import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib_inline.backend_inline

matplotlib_inline.backend_inline.set_matplotlib_formats("png2x") # svg, retina, png2x ...
mpl.style.use("seaborn-v0_8")
mpl.rcParams.update({"figure.constrained_layout.use": True})
sns.set_context("paper") 
sns.set_palette("Set2") 
sns.set_style("whitegrid") 

plt.rc("font", family = "Malgun Gothic")
plt.rcParams["axes.unicode_minus"] = False

# 파일 저장시 파일명의 용이성
def now_time():
    now = datetime.now()
    return now.strftime('%Y%m%d_%H_%M_%S')

# %% [markdown]
# ### 불러오기

# %%
base_dir_1 = 'data_prep/data/_2_after_prep/corpus_method_1/'


with open(base_dir_1 + "sentences.pkl","rb") as f:
    sentences = pickle.load(f)

with open(base_dir_1 + "labels.pkl","rb") as f:
    labels = pickle.load(f)

with open(base_dir_1 + "sentences_corpus_word_index.json","r") as f:
    sentences_corpus_word_index = json.load(f)

with open(base_dir_1 + "label_corpus_word_index.json","r") as f:
    label_corpus_word_index = json.load(f)

# %% [markdown]
# ---
#
# ### 패딩 작업

# %%
# 이렇게 분리 하는 이유 (기존의 트레인 테스트의 tsv를 하나로 합쳤기 때문)
train_sentences, test_sentences = sentences[:15005], sentences[15005:] 
train_labels, test_labels = labels[:15005], labels[15005:]

# %%
decoder_input_data = deepcopy(train_labels) # 디코더의 입력 : end 토큰만 제외
target_sequences   = deepcopy(train_labels)   # 타겟 데이터 : 에서 start 토큰을 제외한 값

# %%
# 정답 라벨에 각 요소별 시작 1 토큰 추가 및 끝토큰 추가
for i in decoder_input_data:
    i.insert(0,1)
for i in target_sequences:
    i.append(2)

# %%
print(decoder_input_data[0])
print(target_sequences[0])
# Out:
# [1, 3]
# [3, 2]

# %% [markdown]
# - 코퍼스 인덱스 : 단어 역변환 (나중에 찾기 쉽게하기 위함)

# %%
sentences_corpus_index_word = {sentences_corpus_word_index[key]:key for key in sentences_corpus_word_index}
label_corpus_index_word = {label_corpus_word_index[key]:key for key in label_corpus_word_index}

# %% [markdown]
# - 패딩 작업

# %%
max_text_len = max([len(i) for i in train_sentences])
text_padded = pad_sequences(train_sentences, maxlen=max_text_len, padding='post')

max_label_len = max([len(i) for i in decoder_input_data])
decoder_input_data_padded = pad_sequences(decoder_input_data, maxlen=max_label_len, padding='post')
target_sequences_padded = pad_sequences(target_sequences, maxlen=max_label_len, padding='post')

# %% [markdown]
# - 전체 코퍼스 크기

# %%
corpus_size = len(sentences_corpus_word_index)
corpus_size_label = len(label_corpus_word_index)
corpus_size, corpus_size_label
# Out:
# (38712, 14)

# %%
# 불러온 데이터 확인하기
for i in sentences[256]:
    print(sentences_corpus_index_word[i], end=' ')

print("")
for i in labels[256]:
    print(label_corpus_index_word[i])
# Out:
# 적 화 다 된거 냐 ? ㅋㅋㅋㅋㅋㅋ 기 가 차다 , 빨갱이 들 이 많긴 많은 가봐 이나라 에
# 기타 혐오

# %%
corpus_size_label
# Out:
# 14

# %%
import model._1_lstm_with_attention_model as model_lstm_att

# %%
model, encoder_model, decoder_model = \
model_lstm_att.seq2seq_with_attention(max_text_len, corpus_size, max_label_len, corpus_size_label)

# %%
# _ = load_model('checkpoint_model1\epoch_0002_metrics_0.1557,0.8384,0.1929,0.7882.h5')
# model.set_weights(_.get_weights())

# %%
# # 모델 학습
# check_path = 'checkpoint_'
# check_path_list = os.listdir(check_path)
# # 학습시
# checkpoint = ModelCheckpoint(check_path + f'/epoch_'+'{epoch:04d}_metrics_{loss:.4f},{accuracy:.4f},{val_loss:.4f},{val_accuracy:.4f}.h5', save_freq='epoch')
# 모델 학습
history_model = model.fit([text_padded, decoder_input_data_padded], target_sequences_padded,
                        validation_split=0.1,
                        epochs=10,
                        # initial_epoch=len(check_path_list),
                        batch_size=64,
                        # callbacks=[checkpoint],
                        verbose=1)

# %%
sets_for_predict = sentences_corpus_word_index,max_text_len, label_corpus_word_index, label_corpus_index_word, max_label_len
moonjang_ = '안녕 하십니까 반가워요?'
model_lstm_att.predict_from_seq(moonjang_, encoder_model, decoder_model, sets_for_predict)
# Out:
# ['clean']

# %% [markdown]
# ### 테스트 데이터를 이용하여 정답 확인

# %%
from tqdm import trange
from IPython.display import display, clear_output

# %%
correct = 0
has_more_than_one = 0
sum_pred = 0
predict_labels=[]
correct_labels=[]
for i in range(len(test_sentences)): #len(test_sentences)):
    test_sentences[i], test_labels[i]
    test_sen = ''
    for j in test_sentences[i]:
        test_sen += sentences_corpus_index_word[j] + ' '
    predict_label = model_lstm_att.predict_from_seq(test_sen, encoder_model, decoder_model,sets_for_predict)
    correct_label = [label_corpus_index_word[k] for k in test_labels[i]]
    sum_pred += 1
    correct += 1 if predict_label == correct_label else 0
    has_more_than_one += 1 if set(predict_label).intersection(set(correct_label)) != set() else 0

    predict_labels.append(predict_label)
    correct_labels.append(correct_label)

    # print(f'''
    # 문제 : {test_sen}
    # 정답 : {correct_label} | 예측 : {predict_label}
    # {('정답!' if predict_label == correct_label else '오답!')}
    # ''')

    clear_output(wait=True)
    print(f'현재 인덱스 진행 ({i}/{len(test_sentences)})')
    print('정답률:',correct / sum_pred * 100)
print('하나라도 겹치는것이 있는 비율:',has_more_than_one / sum_pred * 100)
# Out:
# 현재 인덱스 진행 (3736/3737)
# 정답률: 61.33261974846134
# 하나라도 겹치는것이 있는 비율: 67.995718490768

# %% [markdown]
# ### 틀린 문장 확인해보기

# %%
# 테스트 데이터 number 까지의
number = 10
print("완전 정확히 못맞춘 문장들")
for s,c,p in zip(test_sentences[:number],correct_labels[:number],predict_labels[:number]):
    if c != p:
        sen = ''
        for w in s:
            sen += sentences_corpus_index_word[w] + ' '
        print("문장: ",sen)
        print("정답: ",c,",예측: ",p)
        print(" ")
        
print("-"*100)
print("하나도 못 맞춘 문장들")
for s,c,p in zip(test_sentences[:number],correct_labels[:number],predict_labels[:number]):
    if c != p:
        sen = ''
        for w in s:
            sen += sentences_corpus_index_word[w] + ' '
        if set(c).intersection(set(p)) == set():
            print("문장: ",sen)
            print("정답: ",c,",예측: ",p)
            print(" ")

print("-"*100)
print("하나라도 맞춘 문장들")
for s,c,p in zip(test_sentences[:number],correct_labels[:number],predict_labels[:number]):
    if c != p:
        sen = ''
        for w in s:
            sen += sentences_corpus_index_word[w] + ' '
        if set(c).intersection(set(p)) != set():
            print("문장: ",sen)
            print("정답: ",c,",예측: ",p)
            print(" ")
# Out:
# 문장:  전라도 랑 조선족 페미 합치 면 30 퍼쫌 되지 않노
# 정답:  ['여성/가족', '인종/국적', '지역'] ,예측:  ['여성/가족', '지역']
#
# 문장:  다문화 난 찬성 함 한 녀 들 이 안 대주니깐 그거 라도 찬성 해야 됨
# 정답:  ['여성/가족', '인종/국적'] ,예측:  ['여성/가족']
#
# 문장:  엥 ? 남자 30 대 함소원 50 대 되면 왜 남자 가 함소원 을 버리노 ? 상폐남 을 버리고 더 어린 소 남 으로 갈아타는거지
# 정답:  ['연령'] ,예측:  ['남성', '연령']
#
# 문장:  그래도 지 잡 ㄷㅐ 나온 년 보다는 이대 나온 년 따먹고 싶다 이기
# 정답:  ['여성/가족', '기타 혐오'] ,예측:  ['여성/가족']
#
# 문장:  30~40 대 김치 년 이 많이 있어서 그런 거지
# 정답:  ['여성/가족', '연령'] ,예측:  ['여성/가족']
#
# 문장:  역시 나 민주당 여 성 의원 들 은 주디 꾹 다물고있네요 대단해요
# 정답:  ['여성/가족'] ,예측:  ['여성/가족', '기타 혐오']
#
# 문장:  와 이제야 쌍 도 새끼 들 진심 을 알았다 쌍 도 까면 홍어 로 몰아가는게 컨셉 이 아니라 ㄹㅇ 이었구나 니 네 가 홍어 새끼 들 하고 다를게 뭐 냐 또 네 다홍 지랄 할까봐 적눈 다 김대중 , 노무현 , 이석기 , 마오쩌뚱 개 씨발 새끼
# 정답:  ['지역', '개인지칭'] ,예측:  ['지역']
#
# 문장:  무슬림 은 답 없음 그냥 만나지말고 따로 살자
# 정답:  ['종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  아니 애초 에 염색체 가 다른데 감히 냄져가 여자 가 될라 노 하노 이 와중 에 비 수술 트 렌스 젠더 레즈비언 같운 개똥 같은 소리 하노
# 정답:  ['남성', '성소수자'] ,예측:  ['성소수자']
#
# 문장:  문 재앙 : 이성미 로는 안된다고 !! 손 혜원 빨리 숨겨야해 !!! 생각 없는 기 집 이랑 맘충 들 이나 연 예 기사 에 속지 나머지 놈 들 은 이제 속지 도 않는다고 !!
# 정답:  ['여성/가족'] ,예측:  ['여성/가족', '개인지칭']
#
# 문장:  프랑스 에서 무슬림 들 이 선거권 이 있거든 ㅋㅋㅋㅋ 프랑스 똘레랑스 새끼 들 이야 이 놈 도 뽑고 저 놈 도 뽑는데 무슬림 새끼 들 은 홍어 새끼 들 처럼 우 덜 개슬람 만 뽑는 당 께 ? 법 과 여론 이 누구 를 위해 움직이겠 냨 ㅋㅋㅋㅋㅋㅋ 역사 는 돌고 도 는 것 처럼 이 젠 히 브리 새끼 들 이 유럽 한번 더 먹는거지 뭨 ㅋㅋㅋ
# 정답:  ['인종/국적', '종교'] ,예측:  ['인종/국적', '지역']
#
# 문장:  중 고딩 이 면 김치 녀 라도 상관없는데 ㅎㅎ 물논 24 넘으면 알아서 사라져 야함
# 정답:  ['여성/가족', '연령'] ,예측:  ['여성/가족', '지역']
#
# 문장:  포 궁도 없는 병신 새끼 가 사람 ? ㅋ 뒤져 니 는 그냥 젠 신 병자 .
# 정답:  ['성소수자', '기타 혐오'] ,예측:  ['기타 혐오']
#
# 문장:  병신 일 본 새끼 들 은 사이코 패스 기질 가진 언제 통수 칠 지 모르는 정신병 자 민족 들 이다 ㅋㅋㅋㅋㅋ 중국 은 우리 에게 문물 을 전 해준 어머니 같은 나라고 일본 을 믿느니 중국 을 믿는게 백배 는 더 낫 지
# 정답:  ['인종/국적', '기타 혐오'] ,예측:  ['인종/국적']
#
# 문장:  존나 역겹다 전라도 개 병신 새끼 들 존나 많노 여기 에 좀 꺼지면 안되나 민증 까봐 븅신들 아 난 학생증 깔텡까틀딱들 말 뒤지게 많아 걍 틀니 착용 하고 입 좀 쳐 닫으면 안되나 애 미디 진년 들 아
# 정답:  ['연령', '지역'] ,예측:  ['지역']
#
# 문장:  무슬림 들 에게 전복 당하면 이슬람 율법 을 거부 하는 남자 들 은 가축 마냥 참형 에 처 해 짐 샤리아 체계 아래 자유 와 선택 따윈 없음 죽음 과 복종 뿐
# 정답:  ['종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  여 아든 남아 든 맛 만 좋으면 된다는 놈 들 이 그 놈 들 아니노 여자 한테 선택 못 받고 도태 되면 다 똥꼬 충 되는거노 짐승 도 수컷 들 은 무리 에서 쫓겨나 도태 되면 서로 강간 하고 이러잖노
# 정답:  ['남성', '성소수자'] ,예측:  ['성소수자']
#
# 문장:  원래 이슬람 별로 안 나쁘게 생각 했는데 이제 는 존나 싫다 개 씨발 년 들
# 정답:  ['인종/국적', '종교'] ,예측:  ['여성/가족', '인종/국적']
#
# 문장:  대구 거주 하는 노인 평균 수준
# 정답:  ['연령', '지역'] ,예측:  ['연령']
#
# 문장:  조선족 아니노 ? 그 맘충 이
# 정답:  ['여성/가족', '인종/국적'] ,예측:  ['인종/국적']
#
# 문장:  이슬람 이 짱깨 에게 보복 테러 할시 일단 무슬림 전원 추방 ㅡ > 차마 못 도망간 무슬림 들 인민재판 으로 곳곳 에서 살인 ( 당국 묵인 혹은 지원 ) ㅡ > 무슬림 입국 금지 ..... ㅋㅋㅋㅋ 짱깨 한테 어케 테러 하노
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '종교']
#
# 문장:  30 대 상폐년 이 나이 구라 쳤는데도 속 아 놓고 조오 탄다 ㅋㅋㅋㅋ
# 정답:  ['여성/가족', '연령'] ,예측:  ['연령']
#
# 문장:  ㅋㅋ 그 남 들 상처 받고 집 에서 앙앙 울 다가 앙칼지게 비싼 척 하노 ㅋㅋㅋ 못 생긴 남자 의 삶 이 원래 그렇게 비참한 걸 어쩌겠 냐 이기 야 ㅋㅋㅋ
# 정답:  ['남성', '기타 혐오'] ,예측:  ['남성']
#
# 문장:  김치 와 틀탁 은 뒤져야 한다는 게 여기 서 나오네
# 정답:  ['여성/가족', '연령'] ,예측:  ['여성/가족']
#
# 문장:  다문화 난민 은 우파 좌파 정치인 모두 똑같다 ㅋㅋ
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '개인지칭']
#
# 문장:  양 좆 도 참 교육 해야하는데 한남 옆 에 있으니 노무 비교 된다
# 정답:  ['남성', '인종/국적'] ,예측:  ['남성']
#
# 문장:  ㄴㄴ 90년 대 엄마 애 들 은 오히려 정상 임 근데 80년 대가 걍 ..
# 정답:  ['여성/가족', '연령'] ,예측:  ['여성/가족']
#
# 문장:  나 졸업 한 고등학교 교감 뽀 이 가 교무 실 사무직원 성추행 해서 짤렸노 창놈 새끼 들 후 장이 나 팔아라 이기 야
# 정답:  ['남성'] ,예측:  ['남성', '기타 혐오']
#
# 문장:  이슬람 은 싹 다 없어져야 된다
# 정답:  ['인종/국적', '종교'] ,예측:  ['종교']
#
# 문장:  지 잡 하 나 없어지는게 무 슨상 관 이노 ?
# 정답:  ['기타 혐오', '개인지칭'] ,예측:  ['기타 혐오']
#
# 문장:  똥 성 애 에이즈 99 레즈 에이즈 0 이 것 만 봐도 자지 들 이 문제 란거 알텐데 왜 함께 하는거노
# 정답:  ['남성', '성소수자'] ,예측:  ['성소수자']
#
# 문장:  따 먹힐수만 있으면 에이즈 각 성병 각 100 퍼 라도 부랄딸 랑 이는게 자지 다 이기 야
# 정답:  ['남성', '성소수자'] ,예측:  ['남성']
#
# 문장:  트젠들 은 강간 당하는게 소원 이라는 것 에서 이미 여자 가 아니다 겉 도 속도 유전자 도 뼛속 까지 냄져 임
# 정답:  ['남성', '성소수자'] ,예측:  ['남성']
#
# 문장:  폭동 유공 자 탈북 년놈 들 돈 회수 바람 닭 재인 띠
# 정답:  ['인종/국적', '지역'] ,예측:  ['인종/국적']
#
# 문장:  친 이슬람 유교 개독 한 걸레
# 정답:  ['종교', '기타 혐오'] ,예측:  ['종교']
#
# 문장:  ㅇㅕ 의도 종로 도 아니고 뭔 금융 권 이야 ㅅㅂ 아 삼성 생산 직 노가다 꾼 들 이지 어멋 남편 공고 지만 삼성맨 이 거든 욧 !! 수원 영통구 맘충 마냥
# 정답:  ['여성/가족', '지역', '기타 혐오'] ,예측:  ['여성/가족']
#
# 문장:  개독교 새끼 들 은 정신병 자 이고 위선 자 에다가 악마 이다 이럼 또 죄 짓는다고 지옥 드립 정신병 자 처럼 치겠지 병신 들 이 사실 상 정신 병동 에 갖 쳐야 할 새끼 들 풀어주니까 지랄 하는거 임
# 정답:  ['종교', '기타 혐오'] ,예측:  ['여성/가족', '종교']
#
# 문장:  러쉬 저번 에 똥꼬 충 이 감히 여성 고객 에게 지랄 한 거 보고 믿고 거른다 이기 야 그리고 좆 본 방사 능 에 오염 된 원 재료 쓴다고 하니 불매 나 해야 하노
# 정답:  ['성소수자', '인종/국적'] ,예측:  ['성소수자']
#
# 문장:  옛날 같았으면 쪽팔려서 세상 밖 으로 기 어나 오지 도 못 할 동성애 , 페미 이런 정신병 자 들이 요즘 은 너무 대놓고 당당하게 빽빽 거리 는 세상 이 됨 말세 다 시발 다 피떡 갈비 로 만들어 주고싶다
# 정답:  ['여성/가족', '성소수자', '기타 혐오'] ,예측:  ['성소수자']
#
# 문장:  동성애자 는 정신병 자라는거 이제 좀 알겠냐 ?
# 정답:  ['성소수자', '기타 혐오'] ,예측:  ['성소수자']
#
# 문장:  원래 정신지체 장애인 도 여자 보면 막 달려들어서 덥 친다 티비 드라마 에서 장애 인들 표현 할 때 이쁘게 표현 하지 ? 지랄 실제 로는 여자 보면 그냥 덮 쳐서 강간 할려 고함 ㅋㅋㅋㅋ
# 정답:  ['기타 혐오'] ,예측:  ['여성/가족', '기타 혐오']
#
# 문장:  여기 에 김용호 빠는 개틀 딱 가세 창 병신 들 이 많구나 ㅋㅋㅋ 해운 삼겹 영상 까발려졌는데도 아가리 묵념 하 는 김용호 를 우파 라고 빠는 좆 병신 틀 딱 새끼 들
# 정답:  ['연령'] ,예측:  ['여성/가족', '연령']
#
# 문장:  사우디 개슬람 새끼 들 씨발 밤새도록 음악 존나 크게 쳐 틀어놓고 집 에서 딸딸 이를 치는지 존나 시끄러 움 개새끼 들 씨발 좆 미개 사막 땅 그 지 새끼 들
# 정답:  ['종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  페미 여대 숙대 에 트 렌스 젠더 특별 전형 이라도 있나 ?
# 정답:  ['여성/가족'] ,예측:  ['여성/가족', '기타 혐오']
#
# 문장:  트젠새끼 도 페미 인거 아냐 ? 최한빛 그 새끼 사상 완전 페미나치 그 자체 임 ㅋㅋㅋ
# 정답:  ['여성/가족', '성소수자', '개인지칭'] ,예측:  ['여성/가족']
#
# 문장:  반대 했던 사람 이구나 .. 필리핀 개 더러워 한국 에 사는 필리핀 여자 는 다 쓰레기 야
# 정답:  ['여성/가족', '인종/국적'] ,예측:  ['인종/국적']
#
# 문장:  좌익 들 은 지금 자기 들 이 하고싶은데 로 모든 걸 다 할수있는게 지금 대한민국 현실 임강 력 한 좌파 국가 가 이미 되 버림 미개한 국민 들 이 스스로 좌익 들 에게 힘 을 실어 준것 임 그럼 결과 는 ? 좃 되 봐야 한다 특히 김치 년 들 ...
# 정답:  ['여성/가족', '기타 혐오'] ,예측:  ['여성/가족']
#
# 문장:  좆놈 아 재 상폐 들 다 짜르 고 그냥 일반인 뽑아라 이 니야
# 정답:  ['남성'] ,예측:  ['남성', '기타 혐오']
#
# 문장:  페미니스트 들 은 남자 를 잠재 적 범죄자 로 보기 때문 에 어울리기 힘들지 .
# 정답:  ['여성/가족'] ,예측:  ['여성/가족', '성소수자']
#
# 문장:  괴벨스 의 선동 이론 도 모르느냐 게 헛소리 를 믹스 해놓으니 한남 들 이 노발 대발 한 거 아니겠느냐 이 빻은련 아 네 이 련 웜 상 주 바이러스 걸린련 이 조신 하지 못 하게 어서 가서 베둘레헴 이나 확장 시키거라
# 정답:  ['여성/가족', '남성'] ,예측:  ['남성']
#
# 문장:  한남 이 양 남 한테 쳐 맞으면 피 싸개 똥꼬 충 이 후 장 섹스 하면 똥 싸개 자지 들 은 싸개 싸개 재기 하자 이기 야 ~~
# 정답:  ['남성'] ,예측:  ['남성', '성소수자']
#
# 문장:  양 남좆 에 한남 좆 넣는거 충분히 가능할듯
# 정답:  ['남성', '인종/국적'] ,예측:  ['남성']
#
# 문장:  여성부 만 든 똥 대중 초기 원흉 이 이화 여대생 이라고 봐도 무방 할듯 이 거 맞나 ?
# 정답:  ['여성/가족', '개인지칭'] ,예측:  ['여성/가족']
#
# 문장:  경상도 할배 일듯
# 정답:  ['연령', '지역'] ,예측:  ['지역']
#
# 문장:  정부 에서 대놓고 다문화 처 밀고있네 개 씨발 좆 재앙 새끼
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '개인지칭']
#
# 문장:  대한민국 반공 과 똥꼬 충 을 막 을 최후 의 보루 는 금란교회 라는 말 이 있지 좋던 싫던 빨갱이 들 이 스멀스멀 기어 나오면 기 가 막히게 알아채서 막는게 한기총 이지
# 정답:  ['성소수자', '기타 혐오'] ,예측:  ['성소수자']
#
# 문장:  더 힘들지 . 30 대 중반 까지 남자 들 은 20 대 여자 만 바라봄 . 서른 넘으면 상폐 라 제외 시키는 경우 가 많아 20 대 여자 는 20 대 ~ 30 중반 의 남성 까지 상대 해야 함 . 남녀 비중 이 2:1 이라고 봐야 됨 . 여자 들 의 코 가 높아지는 이유 가 있음 .
# 정답:  ['여성/가족'] ,예측:  ['여성/가족', '연령']
#
# 문장:  똥 남아 짱개 좇선족 전라도 는 한 새끼 도 남김없이 쳐 죽여야 한다
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '지역']
#
# 문장:  난 개인 적 으로 짱깨 보다 무슬림 개 씹 새끼 들 이 더 미개하다 가끔 구내식당 에서 무슬림 개새끼 들 밥처 먹는거 보면 개좃같다 개 병신 씹 새끼 들
# 정답:  ['인종/국적', '종교'] ,예측:  ['인종/국적']
#
# 문장:  세상 에서 중국 과 무슬림 만 없어져도 세계 분쟁 절반 이상 이 해결 될텐데
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '종교']
#
# 문장:  자꾸 니 들 개독 개독 거리 는 데 기독교 에 보수 많아서 기독교 표 무시 못 한다 이명박 도 교회 장로 라서 어느 정도 기독교 표 가 동원 되었음
# 정답:  ['종교', '개인지칭'] ,예측:  ['종교']
#
# 문장:  7-80년 생 여자 빠순히 ㅡ 된장녀 ㅡ 맘충 ( 문슬람 ) 트리플크라운 ㅋ
# 정답:  ['여성/가족', '종교'] ,예측:  ['여성/가족']
#
# 문장:  차별금지법 통과 된 나라 들 부작용 이 얼마나 사회 적 으로 큰 문제 가 되고 있는지나 아시는지 .. 조금 만 더 깊이 알아보고 기사 써주시면 감사하겠어요 .
# 정답:  ['기타 혐오'] ,예측:  ['성소수자', '기타 혐오']
#
# 문장:  잘 했다 ! 기레기 것 들 은 없애야 한다 ! 저 것 들 때문 에 작년 이태원 사태 가 벌어지고 지금 껏 코로나 로 고통 받고 있는데 기레기 들 ! 저 것 들 지 지 한다는 것 들 이 적폐 고 없애야 한다 !
# 정답:  ['기타 혐오'] ,예측:  ['여성/가족', '기타 혐오']
#
# 문장:  다 필요 없고 신안 염전 으로 보내 . 10년 동안 목숨 붙어있는 새끼 들 만 난민 인 정해 준다 .
# 정답:  ['인종/국적', '지역'] ,예측:  ['인종/국적']
#
# 문장:  개독 때문 에 표 날아간건 생각 못 하냐 ㅅㅂ 싸워 ? 개뿔 틀니 새끼 들 이랑 같이 쉰 내 풍기면 서 지랄 떠는게 싸우는거냐
# 정답:  ['연령', '종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  시발 이제 탈북자 넘어오면 신안군 소금 염전 에서 굴리 던 가 북한 으로 돌려 보내자
# 정답:  ['인종/국적', '지역'] ,예측:  ['인종/국적']
#
# 문장:  댓글 드립 에 진지 빠노 개독 이 암만 ㅂㅅ 이래도 저걸 진지하게 말 할리 가 잇냐 무슨 정신병 자도 아니고
# 정답:  ['종교', '기타 혐오'] ,예측:  ['종교']
#
# 문장:  PC 사상 아웃 아웃 아웃
# 정답:  ['기타 혐오'] ,예측:  ['여성/가족', '기타 혐오']
#
# 문장:  스시 남 이 느끼는 한국 년 특징
# 정답:  ['여성/가족'] ,예측:  ['여성/가족', '인종/국적']
#
# 문장:  외노 똥송 여가 정치인 으로 억대 세비 받고 대우 받으면서 한국 을 위해 일 하는게 아니라 지네 삐리삐 리나 위 하는게 욕심 은 존나 많네 시 바르여 어언 뒈져라
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '개인지칭']
#
# 문장:  ★ 알라 가 똥꼬 충 이고 무함마드 도 똥꼬 충 인데 호모 들 을 혐오 하는 희한한 종교 임
# 정답:  ['성소수자', '종교'] ,예측:  ['성소수자']
#
# 문장:  이슬람 바퀴 들 은 좀 추방 좀 해 라 . 사회 에 뭔 도움 이 된다고 받아주냐 .
# 정답:  ['인종/국적', '종교'] ,예측:  ['인종/국적']
#
# 문장:  일단 필리핀 가면 청 부업 자 고용 해라 이기 그러면 가성 비 군무 싸게 재기 시킬 수 있노 . 나도 자댕 이하나 그렇게 재기 시켰노 .
# 정답:  ['남성', '인종/국적'] ,예측:  ['남성']
#
# 문장:  전라도 + 김치 년 + 기독교 = 홍어삼합
# 정답:  ['여성/가족', '지역', '종교'] ,예측:  ['여성/가족', '지역']
#
# 문장:  조선족 들 거의 다 좌파 인 것 도 큰 문제
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '개인지칭']
#
# 문장:  나 한국 이슬람 사원 갔는데 존나 많더라 시발 더 좇같은 건 한국 년 이 히잡 쓰고 있더라 삼겹살 구워서 아가리 에 처 넣어 뿔 라
# 정답:  ['여성/가족', '종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  그게 3 백원 후 장이 라면 ~ 무엇 으로 보상 받나 ~~~ 막심 이 네 게 무심코 ~ 던져 버린 무지개 치료 ~~ 번쩍 드는 정신 ! 소 추 한남 정신 ! 요즘 똥꼬 랍니 다 아으 ~~~
# 정답:  ['남성', '성소수자'] ,예측:  ['남성']
#
# 문장:  서양 냄져는 여자 를 강아지 취급 하고 한국 냄져는 여자 를 가축 취급 함 .
# 정답:  ['남성', '인종/국적'] ,예측:  ['여성/가족', '인종/국적']
#
# 문장:  유독 현재 애 들 엄마 들 맘충 들 이 수준 이하 의 매너 와 민 도를 갗춤
# 정답:  ['여성/가족'] ,예측:  ['여성/가족', '인종/국적']
#
# 문장:  조권 존나 역겹긴 한데 .. 근데 저런거 밀어 준다고 게이 아닌 사람 이 게이 가 되냐 ?
# 정답:  ['성소수자', '개인지칭'] ,예측:  ['성소수자']
#
# 문장:  1 번 도 좆타 낚 여서 들어온 좆놈 들 부랄 발광 자 드르르 할듯
# 정답:  ['남성'] ,예측:  ['남성', '기타 혐오']
#
# 문장:  김치 녀 ㅡ 김치 녀 레즈 존나 기대되 네 ㅋㅋㅋㅋ 서로 의 지갑 을 물어 뜯는 개싸움
# 정답:  ['여성/가족', '성소수자'] ,예측:  ['여성/가족']
#
# 문장:  좆팔 눈갱 길거리 에서 지나가는 파오 후 아닌 일반 남 대충 잡아다 화장 시켜도 저 정도 는 나오겠노 . 저런 걸 돈 써가며 빠는 년 들 은 눈알 이 다 들 동태 들이노 ? 나도 어릴 때 연예 잦 라이트 하게 빨긴 했지만 한남 은 취급 도 안 하고 예쁘장한 양 잦 들만 취급 했노 .
# 정답:  ['남성', '인종/국적'] ,예측:  ['남성']
#
# 문장:  20년 후 . 인구 의 20 프로 를 차지 한 개슬람 은 자기 들 이 먹어선 안 될 고기 들 을 먹었다고 토종 인들 의 목 을 썰기 시작 하는데 ... 국내 정치인 들 은 이 에 맞서 즉각 적 으로 개슬람 으로 종교 를 바꿈 을 선언 !
# 정답:  ['인종/국적', '종교'] ,예측:  ['종교']
#
# 문장:  틀 딱 충 자 적자 의 현장 머 단 하노
# 정답:  ['남성', '연령'] ,예측:  ['연령']
#
# 문장:  진중권 니나 페미 해라 페미 는 정신병 임
# 정답:  ['여성/가족', '개인지칭'] ,예측:  ['여성/가족']
#
# 문장:  새벽 시간대 가 틀 딱 좆족 없는 리얼 백수 일베충 만 있는 시간 이라 젤 꿀잼임
# 정답:  ['인종/국적', '연령'] ,예측:  ['연령']
#
# 문장:  부산 쌍 도 자댕 이 새끼 들 전국 에서 키 제일 작고 좆 도 제일 작고 여혐 은 제일 심하노 . 쌍도 가 또 쌍 도 했노 . 쌍 도 남새 끼 들 부터 쳐 죽여야 된다이기 .
# 정답:  ['지역'] ,예측:  ['남성', '지역']
#
# 문장:  일베 새끼 들 이 좆 나 빠는 명박 이 가 조선족 다문화 졸 퍼준건 아노 ? ㅋㅋㅋ
# 정답:  ['인종/국적', '개인지칭'] ,예측:  ['인종/국적']
#
# 문장:  실제 로 조 민 만나면 보빨 존나 게 해 댈 새끼 들 이 인터넷 이라 막말 하네 일베충 들 ㅋㅋㅋㅋㅋ
# 정답:  ['여성/가족', '개인지칭'] ,예측:  ['여성/가족']
#
# 문장:  글 쓴다면서 말투 왜 저러노 존나 저능 아 한남 인 줄 ㅋㅋㅋ
# 정답:  ['남성', '기타 혐오'] ,예측:  ['남성']
#
# 문장:  시발 개병 신련 로마 에서는 로마법 따라라는 말 처럼 지 들이 왓으 면 그나 라 문화 이해 하고 수용 해야지 .. 시발 미개한 샛기들 이 보자 보자하니까
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '개인지칭']
#
# 문장:  레이디 무현 너무하노
# 정답:  ['악플/욕설', '개인지칭'] ,예측:  ['인종/국적', '개인지칭']
#
# 문장:  어짜피 盧 슬람교 가 있는한 이슬람 애 들 는 쪽 도 못 써
# 정답:  ['종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  시발 년 들 아 똥송 민국 일이 나 걱정 해라
# 정답:  ['인종/국적'] ,예측:  ['여성/가족', '인종/국적']
#
# 문장:  똥꼬 는 정치 를 후 장 으로 하노 벌름 거리 는 후 장창 놈 정책 세울 좆물 밖에 안 들어 찬 쀼젤 이래서 냄 저가 정치 를 하면 안되노
# 정답:  ['남성', '성소수자'] ,예측:  ['성소수자']
#
# 문장:  전라도 홍어 들 은 저희 들 서식 하는 곳도 그렇지만 나아가 국가 전체 를 망하게 함 중국 바퀴 들 은 외적 이니 처리 가 쉬울 수 있지만 이 것 들 은 내부 의 적 이니 국가 적 으로 폐해 가 더 큼
# 정답:  ['인종/국적', '지역'] ,예측:  ['지역']
#
# 문장:  지랄 ㅋㅋㅋ 중국 여자 그 자체 가 패미니즘 이야 외국 남한 테 는 환장하며 벌리고 자국 남한 테 는 보빨 ㅋㅋㅋㅋㅋㅋ
# 정답:  ['여성/가족', '인종/국적'] ,예측:  ['여성/가족']
#
# 문장:  개독 이 아무리 쌍욕 을 먹어도 호모 새끼 들 절대 인정 안 하는것 하나 만큼은 킹 정해 줘야 됨
# 정답:  ['성소수자', '종교'] ,예측:  ['종교', '개인지칭']
#
# 문장:  나이 쳐 먹은 스시 녀 데리 고 25 살이 라고 구라 쳐서 일베 쳐 먹을려고 한 거 네 이해 해줘라 상폐 데리 고 살아야되 잖아
# 정답:  ['여성/가족', '인종/국적', '연령'] ,예측:  ['여성/가족']
#
# 문장:  이런데도 탈북자 옹호 하는 개 씨발 틀 딱 새끼 들 부터 사형 시켜 야한다
# 정답:  ['인종/국적', '연령'] ,예측:  ['연령']
#
# 문장:  기레기 : 그룹 이 듣보라 클릭 수 유도 하려면 A 양 이라고 하는게 맞습니다 . 먹고살기 위해 선 어쩔 수 없습니다 . 하긴 뭐 집 에서 좆 긁 좆 긁 하면서 키 보드 로 일베 나 처 하는 샛기들 이 알리 가 없죠 .
# 정답:  ['기타 혐오'] ,예측:  ['기타 혐오', '개인지칭']
#
# 문장:  산이 가 부릅니다 . 기 레 기레기 .
# 정답:  ['기타 혐오', '개인지칭'] ,예측:  ['기타 혐오']
#
# 문장:  진심 이자스민 명치 삼일한 하고싶다
# 정답:  ['여성/가족', '인종/국적', '개인지칭'] ,예측:  ['여성/가족']
#
# 문장:  ㅋㅋㅋㅋㅋ 행동 력 ㅇㅈㄹ ㅋㅋㄱㄲ 정 게 틀 딱 특 ) 김정은 이 박근혜 석방 하 라고 하면 김정은 애국 우파 행동 력 좋은 청년 임
# 정답:  ['연령', '개인지칭'] ,예측:  ['연령']
#
# 문장:  말 이 되노 한 명의 한남 을 소 추로 만들려면 좆국 닭 은 물론 세계 의 닭 이 멸종 일거노 ㅋㅋㅋㅋ
# 정답:  ['남성'] ,예측:  ['남성', '연령']
#
# 문장:  꼴 페미 = 대 깨문 = 사회 악
# 정답:  ['여성/가족'] ,예측:  ['여성/가족', '기타 혐오']
#
# 문장:  역시 무슬림 = 돌대가리 쓰레기 정신병 자 ㅉㅉ 뭘 배운게 있어야 저런 게 귀한줄 알 지 처 먹고 자살 테러 밖에 모르노
# 정답:  ['인종/국적', '종교', '기타 혐오'] ,예측:  ['여성/가족', '종교']
#
# 문장:  이슬람 이 클리토리스 도 자름 ?
# 정답:  ['인종/국적', '종교'] ,예측:  ['인종/국적']
#
# 문장:  차별금지법 은 절때 통과 못 함 왜냐면 보지 맘충 들 이 개 거품 물 고 반대 하 거든 ㅋㅋ 기독교 아니라도 어차피 통과 못 한다 보지 맘충 지 지표 없으면 끝장 나 는 정부 인데 무리수 두겠냐
# 정답:  ['여성/가족'] ,예측:  ['여성/가족', '기타 혐오']
#
# 문장:  무슬림 은 애초 에 아가리 털면 안되는 패배 인종 인데 인구 좀 잇다고 개깝 치는게 문 제 지 이 상황 에서 10~20년 뒤가면 어떻게 될꺼 같냐 인구 청소 시작 한 다 유럽 미국 자국 에서 인구 청소 시작 성공하면 바로 중동 침공 해서 돈 되는거 다 뺏고 여자 는 성노예 될 뿐 3 차 대전 일어나는 기 야 !~~
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '종교']
#
# 문장:  절 라도 기독교 는 믿고 거르자
# 정답:  ['지역', '종교'] ,예측:  ['지역']
#
# 문장:  일베 가 이 젠 주사파 추종 세력 이 되어가노
# 정답:  ['기타 혐오'] ,예측:  ['여성/가족', '기타 혐오']
#
# 문장:  틀 딱 들은 최태민 이랑 박근혜 가 ㅅㅅ 한 팩트 도 인정 안함 홍어 패 는 전두환 도 좆족 홍어 라고 함
# 정답:  ['인종/국적', '연령', '지역', '개인지칭'] ,예측:  ['지역']
#
# 문장:  차별금지법 = 동성애 조 장법
# 정답:  ['성소수자', '기타 혐오'] ,예측:  ['성소수자']
#
# 문장:  한국 20 대 30 대 40 대 김치 년 들 은 역대 최악 임 ㅋㅋ
# 정답:  ['여성/가족'] ,예측:  ['여성/가족', '연령']
#
# 문장:  개씹슬람 개슬람 짐승 람 이 새끼 들 앞 으로 더 몰려 들어올텐데 언젠가 우리 들 이 좆망 슬람 새끼 들 을 몰아내 야할 날 이 올거다 . 파오 후 , 쿰척 .. 쿰척 .
# 정답:  ['종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  김영삼 정부 때 부터 여야 가릴 거 없이 외 노자 나 외국인 정책 에 실패한 결과 지 우리 나라 에 도움 이 될 사람 들 이 아니고 죄다 도움 안 되는 단순 노동자 들임
# 정답:  ['인종/국적', '개인지칭'] ,예측:  ['인종/국적']
#
# 문장:  목사 가 악령 을 쫓을 수 있다고 생각 하는 이유 는 ? 1 . 남 을 속여 돈 을 벌기 위함 2 . 목사 가 정신병 자 둘 중 하나 임 .
# 정답:  ['종교', '기타 혐오'] ,예측:  ['종교']
#
# 문장:  278 // 너 일 본성 님 안 겪어 봐서 모르겠지 ? 50 넘어 틀 딱 다 되가는 남편 일본 성 님 들이 뭐라는줄 아노 ? 6 젖은 낙엽 9 이래 6 젖은 낙엽 9 . 아무리 쓸어 버릴려고 해도 착 들러붙어서 성가시다고 .
# 정답:  ['남성', '연령'] ,예측:  ['연령']
#
# 문장:  전라도 에서 북괴 김씨 3 부자 쳐 빠는 새 키 들 이 바로 저런 부류 임 북괴 주체사상 교가 기독교 의 변형 된 사이비 형태 거든나라 10 창 내고 부정선거 저지른 종중 종북 매국노 민족 반역 공산 독재자 문 재앙 지지율 이 지금 전라도 에서 92 프로 임
# 정답:  ['지역', '개인지칭'] ,예측:  ['지역']
#
# 문장:  피해 여자 가 더 않 생기 게 법률 보완 하고 상담 할수 있는 곳 이 많아 져야 됩니다 그런데 말 입니다 남자 가 다 그런 것 처럼 여론 몰이 하지 맙시 다 그리고 와 국 여자 때문 에 남자 가 엄청 당하는 것 도 취재 하세요
# 정답:  ['여성/가족', '인종/국적'] ,예측:  ['여성/가족']
#
# 문장:  저 목사 세기 뇌 에 왜구 기생충 이 가득 들었구만 ... 북상 도 토착 왜구 와 게독 의 환상 의 콜라보레이션
# 정답:  ['인종/국적', '종교'] ,예측:  ['인종/국적']
#
# 문장:  ㅇㄱㄹㅇㅋㅋㅋㅋ 페미 랑 똥 성 애 랑 뭔 상관 이노 동성애 랑 도 상관없노
# 정답:  ['성소수자'] ,예측:  ['여성/가족', '성소수자']
#
# 문장:  이슬람 = 빨갱이 각국 의 헌법 위 에 샤리아 법 을 세우는게 무슬림 들 의 공동 목표 이자 신앙
# 정답:  ['종교'] ,예측:  ['종교', '개인지칭']
#
# 문장:  양키 야동 보면 뜬금없이 후 장 으로 하는거 나와서 기분 재기 함 . 사람 한테 도 후 장 강요 하잖노 극혐 . 양키 들 10 명 에 1-2 명 게이 라고 한다 조오오오 심해
# 정답:  ['성소수자'] ,예측:  ['성소수자', '기타 혐오']
#
# 문장:  크 씨발 사이다 병신 급식 충 이며 홍어 새끼 며 진짜 틀 딱이며 씨발 틀무 새 홍무 새 병림픽 보면서 암 걸렸는데 개사 이다 네
# 정답:  ['연령', '지역'] ,예측:  ['지역']
#
# 문장:  개슬람 새끼 들 남 의 나라 처 들어가서 사는 주제 에 감 내놔라 배내 놔라 지림
# 정답:  ['종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  잘생겨 봤자 열등 인종 개슬람일뿐 이라고 미친 새끼 들 아 예수님 저 들 을 용서 해주세요 저 들 은 자신 들 이 무슨 짓 을 하는지 모릅니다
# 정답:  ['인종/국적', '종교'] ,예측:  ['종교']
#
# 문장:  인육 젓갈 은 구 라임 . 그건 중남 이나 처 먹는거 2017년 에도 중남 들 인육 먹음 .
# 정답:  ['남성', '인종/국적'] ,예측:  ['인종/국적']
#
# 문장:  무슬림 들 은 서로 형제 라면 서 미친 놈 들 아
# 정답:  ['인종/국적', '종교'] ,예측:  ['종교']
#
# 문장:  글쎄 나 는 동성애 나쁘게 생각 안함 특히 인구 증가 율 이 높은 인도 나 아프리카 에 널리 퍼져야 된다고 생각 함 인 구가 너무 많다
# 정답:  ['성소수자', '인종/국적'] ,예측:  ['성소수자']
#
# 문장:  똥꼬 충 형제 물 하면 보지 봇물 터지겠네
# 정답:  ['여성/가족', '성소수자'] ,예측:  ['성소수자']
#
# 문장:  이슬람 , 기독교 모든 종교 는 말살 해야 한다 .
# 정답:  ['종교'] ,예측:  ['종교', '개인지칭']
#
# 문장:  ㄹㅇ 외노자 다 쫒아 버리고 관광 금지 때리고 이자 슨민 돌려 보내주면 좋겠다
# 정답:  ['인종/국적', '개인지칭'] ,예측:  ['인종/국적']
#
# 문장:  문죄인 개좆 같은데이건 맞는말 아니냐 똥꼬 충 개좆 같은건 너 도 알 고 나도아는데
# 정답:  ['성소수자', '개인지칭'] ,예측:  ['성소수자']
#
# 문장:  똥꼬 충 인데 페미니스트 일리 가 ;; 난 솔직히 자지 에 대한 애착 에서 여 혐 나온다 본다 익 이 .... 물론 페미니스트 가 아닌 냄져는 다 잠재 적 똥꼬 충
# 정답:  ['남성', '성소수자'] ,예측:  ['성소수자']
#
# 문장:  뜰 딱 = 짱깨
# 정답:  ['인종/국적', '연령'] ,예측:  ['인종/국적', '지역']
#
# 문장:  개슬람 은 뭐 다 ?
# 정답:  ['인종/국적', '종교'] ,예측:  ['종교']
#
# 문장:  씨발 똥꼬 충 개세 끼들 부산 , 대구 에서 보이 면 좆 나 패 야 됨 똥꼬 짓 하러면 전라도 가서 해 라 . 안 말린다
# 정답:  ['성소수자', '지역'] ,예측:  ['성소수자']
#
# 문장:  일베 에 암거 하고있는 좃족 홍어 들 도 모두 소탕 시켜주세요 아멘
# 정답:  ['인종/국적', '지역'] ,예측:  ['지역']
#
# 문장:  일베 하는 게 싫은게 아니고 걍 20~30 대인데 새누리당 지지 하고 문재인 싫어하고전라도 싫어하는 경상도 남자 가 싫다는 뜻임 ㅋㅋ 저기 사이트 자체 가 좌좀 아지 매 들 모인 곳 이 잖어
# 정답:  ['여성/가족', '지역', '기타 혐오'] ,예측:  ['기타 혐오']
#
# 문장:  음 .. 저 새끼 들 인구 증가 때문 에 개슬람 자체 랑 전쟁 날거 같 애
# 정답:  ['인종/국적', '종교'] ,예측:  ['종교']
#
# 문장:  미국 = 유대인 , 흑인 , 히스 페닉 우리나라 = 전라도 , 조선족 , 짱깨 유럽 = 이슬람 , 흑인 모두 같은 조건 이라고 본다 일본 정도 만 특이한 건가 ?
# 정답:  ['인종/국적', '지역', '종교'] ,예측:  ['인종/국적']
#
# 문장:  좆팔 두 놈 이 ^ 커플룩 ^ 이노 ? 딱 보니 둘 이 1 + 1 으로 후 장 팔이 하는게 틀림없노 한 마리 사면 옆 마리 는 공짜 겠노
# 정답:  ['남성', '성소수자'] ,예측:  ['남성']
#
# 문장:  당시 인천 부산 은 지금 의 중공 수준 정도 라고 생각 한다
# 정답:  ['인종/국적', '지역'] ,예측:  ['지역']
#
# 문장:  진짜 지지 한 다 . 무슬림 은 정말 악 이다
# 정답:  ['인종/국적', '종교'] ,예측:  ['종교']
#
# 문장:  자이니치 네 틀 딱이 저기 왜 가있냐
# 정답:  ['인종/국적', '연령'] ,예측:  ['연령']
#
# 문장:  아니 겉모습 으로 남여 를 구분 하지 그것 이 아니면 뭘 로 구분 하나 ? 요즘 은 어찌 이상한 사람 들 이 더 큰소리치네 ~^^ 남자 가 여자 옷 을 입든 여자 가 남자 옷 을 입든 그것 은 지 마음대로 지만 , 사회 룰 을 따를것은 따릅시다 ~!!!
# 정답:  ['여성/가족', '남성'] ,예측:  ['여성/가족']
#
# 문장:  개슬람 새끼 들 은 폐경 년 들 도 안 가리네 대단하다
# 정답:  ['종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  이런 좆팔 상폐남 들 줘안 먹 좆팔
# 정답:  ['남성', '연령'] ,예측:  ['남성', '기타 혐오']
#
# 문장:  터키 놈 들 은 가장 최악 의 민족 임 ... 독일 에서도 가장 미움 받고 다 그 이유 가 있음 . 라도 와 비슷
# 정답:  ['인종/국적', '지역'] ,예측:  ['인종/국적']
#
# 문장:  스시 들 은 적어도 서비스 대접 같은건 몸 에 배였는데 한남 은 걍 날건 날 들이노
# 정답:  ['남성', '인종/국적'] ,예측:  ['남성']
#
# 문장:  동남아 유사 인류 새끼 가 협박 을 하네 ????? 동남아 원래 거르 지만 일단 필리핀 창녀 의 나라 이제 부터 제대로 거른다
# 정답:  ['인종/국적'] ,예측:  ['여성/가족', '인종/국적']
#
# 문장:  남자 가 고추 떼고 가시 나 들 보러 간거냐 ? 미쳐 버리겠네 ~~ 여기 서 여자친구 생기 면 동성애 ?
# 정답:  ['성소수자'] ,예측:  ['여성/가족', '성소수자']
#
# 문장:  군무 새 여 혐한 남 극혐
# 정답:  ['남성', '기타 혐오'] ,예측:  ['남성']
#
# 문장:  어휴 씨발 개독 들 극혐 우한 폐렴 이렇게 극성 인데 굳이 예배 따위 해야 되냐 ㅅㅂ 이럴 땐 교회 좀 가지 마라
# 정답:  ['인종/국적', '종교'] ,예측:  ['종교']
#
# 문장:  좀 꺼져라 개슬람 씨발 년 들 아
# 정답:  ['종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  뭔 애비 뒤질 6 여고생 9 타령 이노 상폐 틀 딱 원숭이 갘 ㅋㅋㅋㅋ 예전 에도 즈 그 례수 후 장 처럼 생겼을게 뻔한 놈 이 .
# 정답:  ['남성', '연령', '종교'] ,예측:  ['남성', '연령']
#
# 문장:  절 라도 가 낫냐 ? 무슬림 이 낳냐 ?
# 정답:  ['지역', '종교'] ,예측:  ['지역']
#
# 문장:  개독 + 동성애 난리 부르 스 ...
# 정답:  ['성소수자', '종교'] ,예측:  ['종교']
#
# 문장:  김치 새끼 들 종특 인 생떼 질 과 방 구석 병신 들 코난 놀이 에 관짝 태극기 틀니 새끼 들 콜라보 ㅋㅋ
# 정답:  ['연령'] ,예측:  ['여성/가족', '연령']
#
# 문장:  ㄹㅇ 지 새끼 아닌 유충 이뻐하는 놈 한 명도 못 봤노 간혹 유충 답지 않게 뽀얗고 눈 크고 코 도 오 똑 한 유충 있으면 빨 아 재 끼더라 앵 ?
# 정답:  ['남성'] ,예측:  ['남성', '연령']
#
# 문장:  탈북자 에서도 모태 좌좀 이 있고 모태 우좀 이 있는 법 ㅋㅋㅋ
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '개인지칭']
#
# 문장:  좆 같은 한남 유충 은 발견 즉시 뱃속 에서 갈아 버리고 유충 비빔밥 한 그릇 뚝딱 하면 웜퇘 지 돼서 한남 말살 시킨다 이기 야 .
# 정답:  ['남성', '연령'] ,예측:  ['남성']
#
# 문장:  모르면 몰라도 더 심했을거다 . 만약 병신 같은 일게이 가 홍팍 이나 오유 새끼 들 , 또는 이 것 과 마찬가지 로 여 초 낙태 충 년 들 한테 이 짓 을 당했으면 ㅋㅋㅋㅋ 시발 상상 만 해도 재밌네 ㅋㅋㅋㅋㅋㅋ
# 정답:  ['여성/가족', '지역'] ,예측:  ['여성/가족']
#
# 문장:  남자 페미 ㅋㅋㅋㅋㅋㅋㅋㅋ 99.9% 문 빠 좌좀
# 정답:  ['여성/가족', '남성'] ,예측:  ['여성/가족', '기타 혐오']
#
# 문장:  H ì nh x ă m đẹ p . 베트콩 새끼 들 도 이쁜 년 은 존나 꼴릿 하던데 씨벌 ㅠㅠ
# 정답:  ['여성/가족', '인종/국적'] ,예측:  ['여성/가족']
#
# 문장:  다문화 저렇 레좆 빠지게 추진 하 는 이 유가 뭐 냐 앙망 앙망 ㅜㅜ 국제화 시대 , 3 d 때문 ? 이런 이유 들 도 다문화 가 해결 책 이 아니라는 어떤 게이 글 보고왔다
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '개인지칭']
#
# 문장:  정상 적 인 자지라 면 동성애 를 혐오 할 수 밖에 없다 보지 년 들 이나 동성애 에 환장하지
# 정답:  ['성소수자'] ,예측:  ['여성/가족', '성소수자']
#
# 문장:  통구이 프리 존 경기 북부 살아서 기분 딱 조 타
# 정답:  ['지역'] ,예측:  ['지역', '개인지칭']
#
# 문장:  페미 인데 남자 랑 어떻게 어울림 ? 남자 혐오 하는 애 들 인데 ㅋㅋㅋㅋ
# 정답:  ['여성/가족'] ,예측:  ['여성/가족', '성소수자']
#
# 문장:  걍 백마 는 선진국 영어권 여자 가 제일 괜춘타
# 정답:  ['여성/가족', '인종/국적'] ,예측:  ['여성/가족']
#
# 문장:  개독 년 은 목사 좆집 이라는 오래된 도시전설 이 개 소리 인 줄 알았는데진 짜임 ㅋㅋ 옛날 에 교회 다녔을 때 직접 체험 했는데 목사 새끼 들 다 구멍 동 서 고 새 끈 한 년 들 은 다 한번 씩 따였음
# 정답:  ['종교'] ,예측:  ['종교', '개인지칭']
#
# 문장:  사자왕 께서 기껏 개슬람 줄여주셨더니 지하 에서 우시것노 ㅠ
# 정답:  ['인종/국적', '종교'] ,예측:  ['종교']
#
# 문장:  무슬림 잡아다 삼일 굶 겨놓고 눈 앞 에서 삼겹살 구워다가 입 에 들이밀면 어떤 반응 을 보일까
# 정답:  ['인종/국적', '종교'] ,예측:  ['종교']
#
# 문장:  다르게 말 하면 걍 똥송 과 서양 의 차이 다 종교 가 중요한게 아니야
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '종교']
#
# 문장:  자지 ㅣ 들 말 하는건 보통 자지 소개 라고 6 이슬람 난민 좆 들 한테 단체 로 후 장 따이고 싶다 9 라고 마음속 으로 절절 히 말 하는게 들리노
# 정답:  ['남성', '인종/국적'] ,예측:  ['남성']
#
# 문장:  정신병 꼴 페미 = 나치 + 빨갱이
# 정답:  ['여성/가족'] ,예측:  ['여성/가족', '기타 혐오']
#
# 문장:  완전 또 -- 라이네 . 이런 년 이야말로 징계 먹어 야하는 년 아님 ? ㅋ 하긴 지 면상 으로는 이런 일 일어나는게 이해 가 안되겠지 .
# 정답:  ['여성/가족', '기타 혐오'] ,예측:  ['여성/가족']
#
# 문장:  저 학력 , 저 소득 , 극우 노인 들 이 읽는 신문 조선일보 !
# 정답:  ['연령', '기타 혐오'] ,예측:  ['연령']
#
# 문장:  살면서 걸러 야 할 새끼 들 알라 믿는 새끼 예수 믿는 새끼 짱깨 빠는 새끼 슨상 빠는 새끼 호남 출신 새끼 그리고 우리 일게이 들
# 정답:  ['인종/국적', '개인지칭'] ,예측:  ['인종/국적', '종교']
#
# 문장:  급식 새끼 들 문재인 안철수 누 군 진아 냐 ? 씨발 아
# 정답:  ['연령', '개인지칭'] ,예측:  ['연령']
#
# 문장:  호모 게이 에이즈 병균 똥 고 들 제발 그만 좀 설쳐 대라 ᆢ 정신병 치료 가 필요한 환 우 들이 정치 한다고 설져 대니 ᆢᆢ 심상정 같은 애가 꿀빨 지
# 정답:  ['성소수자', '개인지칭'] ,예측:  ['성소수자']
#
# 문장:  정신병 은 물리치료 김치 녀 는 삼일한
# 정답:  ['여성/가족', '기타 혐오'] ,예측:  ['여성/가족']
#
# 문장:  늙은 년 이란 데 서 맘충년 들 가장 빡쳤을거 같 닼
# 정답:  ['여성/가족', '연령'] ,예측:  ['여성/가족']
#
# 문장:  급식 충 이랑 급식 충 부모 만나면 녹음 해라 전 라돈 지보 게
# 정답:  ['연령', '지역'] ,예측:  ['연령']
#
# 문장:  걍 나였으면 킹오파 야마자키 로 빙의 해서 애 새끼 랑 맘충년 양 손 으로 잡아서 3회 땅바닥 에 내 리까 고 칼빵 갈 겼다
# 정답:  ['여성/가족'] ,예측:  ['여성/가족', '지역']
#
# 문장:  전라도 년 의 본성 을 이제야 깨 닳은 갱 상 도 년 들
# 정답:  ['지역'] ,예측:  ['여성/가족', '지역']
#
# 문장:  뒤 에서는 젠신 같은 말투 로 여자 패기 시전 하는데 웜년들 눈 에 흉 자 로 보일 수도 있는 거지 본인 마냥 앵 나 집착 하노 .
# 정답:  ['성소수자'] ,예측:  ['여성/가족', '성소수자']
#
# 문장:  개독 도 좃 같긴하지만 개독 까진 인정 해준다 씹 슬람 은 척살척결 인종청소 가 답
# 정답:  ['인종/국적', '종교'] ,예측:  ['종교']
#
# 문장:  여자 들 이 성소수자 라면 무조건 떠받 들어줄줄 알 고 여대 안 에서 여왕벌 노릇 하려 들었다가 의외로 실패하니 머리 가 띵하지 ?
# 정답:  ['여성/가족', '성소수자'] ,예측:  ['성소수자']
#
# 문장:  너련 말 이 맞노 중국 도 개돼지 많아서 유행 타는 시기 가 좆국 처럼 빠르노 중국 홍콩 있으면서 한류 때문 에 코르셋 하나 씩 주 워드 는 꼴 보고 기함 했노 현재 여자 아이돌 위주 한류 같은것도 사실 상 사라져 야하노
# 정답:  ['인종/국적'] ,예측:  ['여성/가족', '인종/국적']
#
# 문장:  인도 는 불교 라는 종교 때문 에 망할것이다 ... 이런 심각한 사태 에도 답 이 없다 ... 저렇게도 못 깨닫나 ..,
# 정답:  ['인종/국적', '종교'] ,예측:  ['종교']
#
# 문장:  난 동 생애 보다 종교 새끼 들 이 더 싫음 예수 쟁이 들이 믿는 그 하나 새끼 가 만든게 게이 아님 ? ㅋㅋ
# 정답:  ['성소수자', '종교'] ,예측:  ['종교']
#
# 문장:  무슬림 청년 끼리 데스 매치
# 정답:  ['인종/국적', '종교'] ,예측:  ['종교']
#
# 문장:  홍어 는 원래 좆 같은 놈 들 이고 원래 일베 에 뉴스 퍼 나르는 새끼 들 있었음 틀 딱이 과 하게 하는거는 문제 있고 머 가리 텅텅 빈 급식 충 들 도 씹 극 혐 유머 를 종범 영양가 없는 공감 글 특징 글 존나 올라옴
# 정답:  ['연령', '지역'] ,예측:  ['지역']
#
# 문장:  이 새끼 레즈 바 에서 여자 인게 유세 냐 고 웅애 웅 한 놈 아니노 ? ㅋㅋㅋ 하다못해 개독 똥꼬 도 빠노
# 정답:  ['성소수자', '종교'] ,예측:  ['성소수자', '기타 혐오']
#
# 문장:  왜구 들 이 박영선 이 가 나오길 바라는거 쥐 ?
# 정답:  ['인종/국적', '개인지칭'] ,예측:  ['인종/국적']
#
# 문장:  개슬람 이 다수 가 되면 가장 먼저 공격 당할 곳 이 교회 인데 목사 제 정신 이노 ? 지가 예멘 가면 대우받을 줄 아노 ? 참수 나 안당 하면 다행 인 거지
# 정답:  ['인종/국적', '종교'] ,예측:  ['종교']
#
# 문장:  개좆 같은 씹 독새 끼 들 은 바퀴벌레 임 진짜 개독 씨발 년 들 만 모아서 중국 에서만 따로 살 면 좋겠다
# 정답:  ['종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  7시 가서 민폐 부리 지 않는 이상 니 그 나라 로 꺼져 !!
# 정답:  ['인종/국적', '지역'] ,예측:  ['인종/국적']
#
# 문장:  무슬림 이 테러 하고 다니는 이유 : 새로운 나라 에 도착 한다 -> 열심히 살다가 신앙 생활 에 불편함을 느낀다 -> 기존 살던 국민 들 과 충돌 한다 -> 점점 증오 가 쌓인다 -> 자기 가 살 고 있는 나라 를 바꿔야 겠다는 생각 을 한다 -> 폭탄 을 터뜨린다
# 정답:  ['인종/국적', '종교'] ,예측:  ['인종/국적']
#
# 문장:  트 렌스 젠더 ㆍ 게이 등 이런 사람 들 정신병 자 맞다 왜 신의 영역 을 거 스르 는가 인간 은 태어나면서 성별 이 정해지는 법 그것 을 바꿀려는 게 정신병 이지
# 정답:  ['성소수자', '기타 혐오'] ,예측:  ['성소수자']
#
# 문장:  어디 섬 이나 도시 하나 완전 폐쇄 하고 군대 가 출입통제 하면서 성소수자 , 페미나치 들 몰아 넣고 알아서 생존 하 라고 했으면 좋겠다
# 정답:  ['여성/가족', '성소수자'] ,예측:  ['여성/가족']
#
# 문장:  잘 했노 개 짓거리 하러 동남아 가는 새끼 들 이 뚫린 주둥아리 라고 나불나불 한남 좆 병신 들 은 모가지 따야 조용해지노
# 정답:  ['남성', '인종/국적'] ,예측:  ['남성']
#
# 문장:  한인 이민 충 특징 : 현지 에서는 세탁소 똥 송칭 챙총 이면 서 일베 만 오면 천조국 게이 , 천조국 응딩 이라 면서 온갖 허세 다 부림
# 정답:  ['인종/국적', '개인지칭'] ,예측:  ['여성/가족', '개인지칭']
#
# 문장:  집안 대 대로 기독교 집안 인데 진짜 개독 혐오 증 이 안 생길 래야 안 생길수가 없다 21 세기 에 종교 진심 으로 믿는 새끼 들 은 개빡 대가리
# 정답:  ['종교'] ,예측:  ['종교', '기타 혐오']
#
# 문장:  개쌍 도 아니라서 예지력 하락
# 정답:  ['지역', '개인지칭'] ,예측:  ['지역']
#
# 문장:  무슬림 장애 력 ㅍㅌㅊ ?
# 정답:  ['종교', '기타 혐오'] ,예측:  ['종교']
#
# 문장:  페미 는 알아서 잘 제거 하겠네 ㅋㅋㅋ 뭐 민주당 뽑는 보지 들 이 원하던 세상 아니냐 ??? 무분별 한 조선족 동남아 외노자 이슬람 난민 받아들이는거 전부 다 인권 팔이 민주 팔이 민주당 좌파 정권 새 키 들 작품 이니
# 정답:  ['여성/가족', '인종/국적', '종교', '기타 혐오'] ,예측:  ['여성/가족', '인종/국적', '종교']
#
# 문장:  트위터 사용 방법 이 복잡해서 그동안 안중 에도 없었는데 저런 패션 페미 들 이 판 치고 다니면서 본인 들 이 주류 라 망상 질 할거 상상 하니 구역질 나노 . 바로 트위터 가입 하러 간다 이 니야
# 정답:  ['여성/가족'] ,예측:  ['여성/가족', '성소수자']
#
# 문장:  저 맘충 도 결국 은 광주 인데 정부 에서 안 보호 해주냐 ??
# 정답:  ['여성/가족', '지역'] ,예측:  ['여성/가족']
#
# 문장:  탄핵 파 이 새끼 들 이 짱깨 랑 메 갈 알바 쓰는거 임
# 정답:  ['여성/가족', '인종/국적'] ,예측:  ['여성/가족']
#
# 문장:  전라도 노인 일듯
# 정답:  ['연령', '지역'] ,예측:  ['지역']
#
# 문장:  착 슬죽슬착한좆슬 람 은 죽은 좆슬람 뿐 이다 아니 좆슬람 새끼 착하게 해줬는데 무 ' 슨 ' 범죄 노
# 정답:  ['인종/국적', '종교'] ,예측:  ['인종/국적', '개인지칭']
#
# 문장:  진짜 똥 고충 새끼 들 한남 안 먹는 워마드 응원 해야지 아니가 ?
# 정답:  ['남성', '성소수자'] ,예측:  ['남성']
#
# 문장:  한 남충 보다 틀 딱충이 더 싫다는 말 과 같은 말 아니겠 읍 니까 ? 싫은 것 * 싫은 것 은 더 싫은 법 이지 요
# 정답:  ['남성', '연령'] ,예측:  ['연령']
#
# 문장:  남 : 김치 녀 된장녀 ~~ 여 : 한 남충 느 개비 ~ 남 : 페미 들 남성혐오 심각 ???
# 정답:  ['여성/가족', '남성'] ,예측:  ['남성']
#
# 문장:  한국 남자 는 남자 도 아니고 똥꼬 충 과 같은 끔찍한 돌연변이 다
# 정답:  ['남성', '성소수자'] ,예측:  ['성소수자']
#
# 문장:  여자 나 다문화 는 장애인 이랑 같은 급 이니까 이해 한 다 ㅋ
# 정답:  ['여성/가족', '인종/국적', '기타 혐오'] ,예측:  ['여성/가족', '개인지칭']
#
# 문장:  개슬람 은 홍어 들 이랑 똑같아 밖 으로는 아닌듯 코스 플레 하지만 결정 적 인 순간 에 직 들 종특 나옴
# 정답:  ['지역', '종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  동남아 는 중국 이랑 먼데도 95% 화교 가 쥐고있는데 바로 옆 대한민국 은 짱깨 놈 들 ?? 엥 ? 그거 요리사 아니냐 ? 이 수준 밖에 못 됨 박정희 녹 림화 랑 화교 탄압 정책 은 ㅆㅅㅌㅊ 다
# 정답:  ['인종/국적', '개인지칭'] ,예측:  ['인종/국적']
#
# 문장:  북괴 들 이랑 좆족 똥 남아 로 도 벅차는데 쟤 들 까지 받으면 ㄹㅇ 헬센 확정 아니냐 ? 지 나라 아니라고 함부로 지랄 하는 개슬람 새끼 들 은 추방 이 답 .
# 정답:  ['종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  무슬림 은 죄 짓지 않아도 센 조 이하 네 사스 갓 범죄 에 최적화 된 인종
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '종교']
#
# 문장:  아냐 새끼 야 ㅋㅋ 펨코 애 들 은 선비 질하다가 페미 이슈 로 갓 끈 정도 푼거고 일베 는 태생 부터 빤스벗 고 페미 보지 째던 사이트 야 . 니 가 급식 충 이라 뭘 모르는거야
# 정답:  ['연령'] ,예측:  ['여성/가족', '연령']
#
# 문장:  헐 끔찍하다 남 의 나라 에서도 종교 질 ㅡ 아 싫다 무교 가 답 이다
# 정답:  ['인종/국적', '종교'] ,예측:  ['종교']
#
# 문장:  한 녀 들 히잡 차도르 쓰고 운전 도 못 하고 경기장 도 못 들어가는 날 머 지 않았네 돼지고기 도 못 묵고 코 오란 잘못 간수 했다고 테러 당 하고 화형 당 하고 강간 당했는데 가족 명 예 실 추시 켯다 고 가족 들 한테 오히려 명예살인 당 하고 아닌거 같지 ???? 유럽 봐라 이슬람 애 들 이 어떻게 하고있나 .
# 정답:  ['여성/가족', '인종/국적', '종교'] ,예측:  ['인종/국적', '개인지칭']
#
# 문장:  sns 에서 대놓고 명품 이나 가구 같은거 자랑 질하는 년 들 은 실제 로는 돈 도 별로 없는 어중간한 계층 임 진짜 부자 들 은 골프 치러 필드 나가거나 파티 에 초대 해서 자연 스럽게 저런 말 주고받음
# 정답:  ['여성/가족', '기타 혐오'] ,예측:  ['여성/가족']
#
# 문장:  오늘 제일 기쁜 소식 이 설리 가 최소 자지 버린거노 ~^ 느 ^ 한남 들 이 아무리 자 들자 들거려 봤자 타 격감 0 인 쀼젤 ~ 상폐남 이 탑 연예인 한테 차이 니까 감정이입 됐나 보노 ㅋㅋㅋㅋㅋ
# 정답:  ['남성'] ,예측:  ['남성', '연령']
#
# 문장:  항문성교 가 먼 자랑 이라고 광장 에 나와서 하겠다고 참 ... 이 게 다 박원순 시장 이 광장 사용승인 해줬기 때문 이야 신천지 도 게이 들 도 다 ~~~ 에잇 !!! 특권 중 의 특권 자 들 !!!!
# 정답:  ['성소수자', '개인지칭'] ,예측:  ['성소수자']
#
# 문장:  개슬람 새끼 들 또 시 동거 네 개새끼 들 이 뿌리 만 박으면 돼지고기 타령 부터 시작 하더라 애 미 뒤진 씹 창년 들 저 새끼 들 이 싸지른 개슬람 종자 들 성인 될 때 쯤 이 면 이 나라 도 좆 같아지겠네
# 정답:  ['종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  시발 개슬람
# 정답:  ['인종/국적', '종교'] ,예측:  ['종교']
#
# 문장:  애초 에 무슬림 새끼 들 안 받는 이유 가 테러 위험 인데 돈 있는 씨발 새끼 들 이 뭣 하러 테러 를 일으키겠냐 ?
# 정답:  ['종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  목사 하면 여 신도 들 이랑 무제한 섹스 가능 ?
# 정답:  ['여성/가족', '종교'] ,예측:  ['종교']
#
# 문장:  꼴 페미 들 을 상종 못 하는 이유 = 정신병
# 정답:  ['여성/가족', '기타 혐오'] ,예측:  ['여성/가족']
#
# 문장:  만약 에 존나 귀엽고 이쁜 ㄹㄹ 여자애 가 저랬으면 로리 충 들 선착순 존나 뛰어갔겠지
# 정답:  ['여성/가족', '연령'] ,예측:  ['여성/가족']
#
# 문장:  목사 는 개 나소 나 되나 봐요 하긴 전광훈 도 목사 라고 하던되 애비 죄 사함하기 위해 쇼쇼쇼 하는가
# 정답:  ['종교', '개인지칭'] ,예측:  ['종교']
#
# 문장:  이슬람 난민 , 이민자 가 폴란드 에 많냐 ? 별로 없 는걸 로 아는데 .. 무슬림 도 보는 눈 이 있는데 의료 , 복지 잘 되어있고 일자리 많은데로 가지 . 독일 영국 프랑스 같은데로
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '종교']
#
# 문장:  동성애자 차별 한적 이 없어요 신찬 지도 차별 한적 없고 왜 이 걸 굳이 법 으로 만들려하나요 그렇게 할 일이 없어요 ?? 신천지 나 동성애자 들 이나 그냥 불쌍한 사람 들이죠 이 걸 이용 하지 마시죠 당신 들 이 뭘 하고 싶은지 아니까 욧
# 정답:  ['성소수자', '종교'] ,예측:  ['성소수자']
#
# 문장:  ㅋㅋㅋㅋ 맞다 ㅋㅋㅋ 쌍 도개 병신 들 맞는데 김대중 노무현 홍어 들 이 ㄱ 씹 극 혐 병신 이라 용 ㅅㅓ 됨
# 정답:  ['지역', '개인지칭'] ,예측:  ['지역']
#
# 문장:  홍 통일체 개쌍 도 새끼 들 부심 좀 부리지마라 좆 같은 빨갱이 새끼 들 아 ㅉㅉㅉ 노무현 문재인 개쌍 도 ^^
# 정답:  ['지역', '개인지칭'] ,예측:  ['지역']
#
# 문장:  문재인 이 가 또 ....
# 정답:  ['악플/욕설', '개인지칭'] ,예측:  ['악플/욕설']
#
# 문장:  하 대구 사는 여자 맨 발가락 빨고싶다 대구 여자 들 이쁘다는대 ㅜ
# 정답:  ['여성/가족', '지역'] ,예측:  ['지역']
#
# 문장:  대줘서 그런거 아니겠노 양 자지 한테 후 장 개통 당 하고 그 맛 못 잃어서 걸레 창남 들
# 정답:  ['남성', '인종/국적'] ,예측:  ['남성']
#
# 문장:  송파 옆 에 위례 인지 동탄 인지 씹 창 난 맘충 도시 아니냐 ? ㅋㅋ ㄹㅇ 송파 가 ? 강남 집값 이 50 퍼 올라도 재앙 이 씹기 바쁜데
# 정답:  ['여성/가족', '지역', '개인지칭'] ,예측:  ['여성/가족', '개인지칭']
#
# 문장:  양 남 이랑 해도 성병 걸리노 한 남충 이 성병 덩어리 라고 하면 양 자지 랑 섹스 하는 윾입 새끼 들 있을까봐 알려주노 자지 와의 섹스 는 성병 직행 열차 노 차라리 아들 을 쳐라 이 기 야노
# 정답:  ['남성'] ,예측:  ['남성', '인종/국적']
#
# 문장:  전라도 새끼 들 은 저 돈 못 받으면 이명 박근혜 탓 할거 부터 찾아봄
# 정답:  ['지역', '개인지칭'] ,예측:  ['지역']
#
# 문장:  조팔 저 게 18년 도 선진국 에서 일어나는 일이 라니 믿을수가 없노 내 조국 좆 되 기전 에 무슬람 좆 새끼 들 막아 야하노 전세계 가 지구 상 어디 도 없는 한남 을 이긴 여 혐좆 들 한테 정복 당하게 생겼노
# 정답:  ['남성', '인종/국적', '개인지칭'] ,예측:  ['남성']
#
# 문장:  짱깨 랑 이슬람 새끼 들 한 곳 에 모아놓고 핵 으로 조졌으면 좋겠다
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '종교']
#
# 문장:  돼지 등신 꼴 페미 들 전략 이 배려 받으면 감사할줄 알아야 한다 라고 한 김 나 정 아나운서 에게 김치 녀 된장녀 이미지 뭍 히 기 다
# 정답:  ['여성/가족', '개인지칭'] ,예측:  ['여성/가족']
#
# 문장:  서유럽 에 단체 관광 갔다가 키 190 궁뎅 이 빵빵 한 금발 미남 자집놈 봤는데 나도 모르게 웃음 이 나더노 ㅋㅋㅋㅋ 나 뿐 아니라 나 랑 같 이간 한국 여자 들 다 그랬음 ㅋㅋㅋㅋ 자집 애가 얘쁘 면 반 사적 으로 입 꼬리 가 올라간다 이기 야 ^ 노 ^
# 정답:  ['남성', '인종/국적'] ,예측:  ['남성']
#
# 문장:  개쌍 도 왜구 ㅅㄲ 갱생 불과 화장 형 요망
# 정답:  ['인종/국적', '지역'] ,예측:  ['지역']
#
# 문장:  원래 기독교 는 이슬람교 개종 가능 . 저 는 이슬람교 개종 하면 이슬람 화 목표 하겠지 ㅋㅋ 니 들 한국 미래 걱정 할테니 ㅎㅎ 아니면 개종 하지 않고 일본 이민 할거다 . 일본 에 이슬람 화 안된 제국주의 땜 일본 화 진행중 .. 중국 은 이슬람 화 사라지고 중국화 강력하다
# 정답:  ['종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  틀 딱 홍어 썅년 으로 추정 됨 . 아니 지 가족 이 익사 했으면 그렇게 쉽게 실족 사라 고 인정 할까 ? 아 ... 가족 이 없는 틀 딱 홍어 썅년 들 인가 ?
# 정답:  ['여성/가족', '연령', '지역'] ,예측:  ['연령']
#
# 문장:  대구 경북 봉쇄 하자 그냥 봉쇄 반대 하는건 존나 비 양심 적 아니냐 ? 같이 뒤지자 이런 건가 .. 짱깨 새끼 들 도 아니고
# 정답:  ['인종/국적', '지역'] ,예측:  ['인종/국적']
#
# 문장:  비혼 력 높이 고 싶은련 들 가면 되겠노 망혼 이 얼마나 한남 좆물 같은지 증명 해주는 산 증인 들이노
# 정답:  ['여성/가족', '남성'] ,예측:  ['남성']
#
# 문장:  연변 하고 길림 하고 흑룡 이 있던데야 들도 전라 경상도 처럼 웬 수지 간 이 던데 ㅋㅋ 625 떄 짱깨 편 에 서서 국군 미군 도륙 한 게좃족 인데 그 후손 들 이 또 한국 에서 돈버 네 어찌 보면 철천지원수 인데 .. ㅋㅋ
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '지역']
#
# 문장:  담 부턴 반박 하지말고 바로 품평 해줘라 이기 야 늙은 한남 아 너 는 참 늙었다 한남 아 너 는 늙어 보이는데 무슨 소 리노 늙은 네 얼굴 을 봐라 네 뱃살 을 봐라 다 모르겠고 너 는 앵 나 늙고 흘러내린다 관리 좀 해야겠다 요즘 운동 은 하는거냐 해 버려라 이기 야 자기검열 하게하고 눈치 보게 만들어 야하노
# 정답:  ['남성', '연령'] ,예측:  ['남성']
#
# 문장:  홍어 깜댕 이 개슬람 이 개새끼 들 은 일생 차별 받았다고 지랄 들 이야
# 정답:  ['인종/국적', '지역', '종교'] ,예측:  ['종교']
#
# 문장:  드물게 보이노 . 게이 팝 에 환상 가지 고 한국말 배워서 모델 일 하는 러시아 여자 양 아치 한남 자댕 이 만나노
# 정답:  ['여성/가족', '남성', '인종/국적'] ,예측:  ['남성']
#
# 문장:  에세 머 들 이 애초 에 엣날 에 웜 지지 했는지도 몰랐노 젠 신 병자 에 관심 소 추 만큼도 업었노
# 정답:  ['남성', '성소수자', '기타 혐오'] ,예측:  ['성소수자', '기타 혐오']
#
# 문장:  난 개독 좆 나 싫어하는데 진짜 쟤 네 들이 행 게이 는 행 게 이 임안 그러면 개슬람 , 좌좀 , 동성애 뭐 이런 새끼 들 지금 보다 세력 수십 배 는 더 불렸다
# 정답:  ['성소수자', '종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  아무리 맘 카페 가 개 씹 븅 신년 이여 도 지금 탄핵 반대 를 할까 ?? 난 조선족 같음
# 정답:  ['여성/가족', '인종/국적'] ,예측:  ['여성/가족']
#
# 문장:  진짜 쳐 죽이고싶네 개슬람 새끼 들
# 정답:  ['인종/국적', '종교'] ,예측:  ['종교']
#
# 문장:  무슬림 이 원래 근 친 상 간 이 많아요 . 사촌 끼리 결혼 도 많고 . 조 혼도 많고 ……………… 거기 에 강간 을 해놓고도 여자 가 그걸 증명 해야 함 . ㅁ ㅅ ㄹ …….. 정말 답 없어
# 정답:  ['인종/국적', '종교'] ,예측:  ['여성/가족', '종교']
#
# 문장:  지난 4 , 년 동안 조작 질 국 짐당 무얼 숨기려고 막말 했을까 에 라 미친 개 후쿠시마 던져 버리야 하는데 왜구 시 키 들
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '개인지칭']
#
# 문장:  개슬람 새끼 들 싹 다 쓸어 버리자
# 정답:  ['종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  왠 빻 은 타코야끼 가 지 손가락 빨고있노 좆 국철 에 사람 한테 감히 말거는 장애 좆 들 흑 좆 나 많노 배때 지 깔 푹찍 해줘야 하노 ^ 오 ^
# 정답:  ['남성', '기타 혐오'] ,예측:  ['남성']
#
# 문장:  개독 이나 무슬람 이나 씨발 둘다 병신 들
# 정답:  ['종교'] ,예측:  ['종교', '기타 혐오']
#
# 문장:  도태 남 들 과 장애인 , 미혼 , 이혼 남 들 을 위해 섹스 서비스 는 합법 화 되야 한다 . 매매 라는 부정 적 어감 도 바뀌어야 됨 . 창녀 는 엄연히 4 차 산업 인 서비스업 종사 자 다
# 정답:  ['여성/가족', '남성'] ,예측:  ['여성/가족']
#
# 문장:  박사모 틀 딱 새끼 들 어떻게 까 내릴지 혼동 하는 클라스 ㅋㅋㅋㅋㅋㅋㅋ 좆족 이라고 까지도 못하쥬 ? ㅋㅋㅋㅋㅋ
# 정답:  ['인종/국적', '연령'] ,예측:  ['연령']
#
# 문장:  ㅋㅋㅋ 무슬림 혐오 반대 래 ㅋㅋ 무슬림 은 똥꼬 충 을 혐오 할텐데 ㅋㅋㅋ 일방 적 인 짝사랑
# 정답:  ['성소수자', '종교'] ,예측:  ['성소수자', '기타 혐오']
#
# 문장:  도피 충 들 해외 가서 이슬람 하고 다를게 없네
# 정답:  ['종교', '기타 혐오'] ,예측:  ['인종/국적', '종교']
#
# 문장:  무슬림 은 가부장 의 극치 아니냐 ? 근데 어떻게 김치 녀 들 이 견디면서 살 지 ?
# 정답:  ['여성/가족'] ,예측:  ['여성/가족', '인종/국적']
#
# 문장:  그냥 전라도 출신 , 강간 성추행 전과자 , 남성성 자체 에 트라우마 를 가지 고 있는 저 지능 성소수자 제외 하고 최소한 의 사람 구실 이라도 하는 20 대 남자 는 죄다 문재인 싫어한다고 보면 됨 . 그냥
# 정답:  ['성소수자', '지역', '기타 혐오', '개인지칭'] ,예측:  ['지역']
#
# 문장:  남자 저 정도 외모 면 북한 에서 ㅆㅅㅌㅊ 아니냐 ? 국적 세탁 하 면 김치 녀 도 따먹을 클라스 아니냐 ??
# 정답:  ['여성/가족', '남성', '인종/국적'] ,예측:  ['여성/가족']
#
# 문장:  신창원 , 유영철 , 정남규 하나같이 전라도 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 정답:  ['지역', '개인지칭'] ,예측:  ['지역']
#
# 문장:  전라도 , 이슬람 같은 배타 주의자 들 은 다른 사람 끼리 힘 합쳐서 무 찔러 야함
# 정답:  ['지역', '종교'] ,예측:  ['지역', '개인지칭']
#
# 문장:  그래서 유충 유충 하는거 아니겠노
# 정답:  ['남성'] ,예측:  ['남성', '연령']
#
# 문장:  개독교 는 5.18 처럼 싹 다 구라 야
# 정답:  ['지역', '종교'] ,예측:  ['종교']
#
# 문장:  6 . 6 똥 남충 들
# 정답:  ['남성', '인종/국적'] ,예측:  ['남성']
#
# 문장:  둘다 문제 다 똥꼬 충 ++ 무슬림
# 정답:  ['성소수자', '종교'] ,예측:  ['성소수자', '기타 혐오']
#
# 문장:  개슬람 새끼 들 은 존중 이라 는걸 몰라서 안됨 박수 도 양쪽 이 맞아야 나는거지 ㅅㅂ
# 정답:  ['종교'] ,예측:  ['여성/가족', '종교']
#
# 문장:  작년 에 그렇게 아 묻 따 보지 뽑으 랬 는데도 정신 못 차리고 쌍 도 틀 딱 이니 뽑은 것 들 때문 에 완벽한 자지 독재 국 됐노 . 뒤늦게나마 쎄 한 거 눈치 챈 년 들 이라도 끌어 모아서 좆불 시위 열어야 된다이기 재앙 이 탄핵 시켜야 되노
# 정답:  ['남성', '연령', '지역', '개인지칭'] ,예측:  ['지역']
#
# 문장:  씨발 전라도 는 끼 여야 하 지만 " 오늘 도 홍어 가 만선 이구나 " ??? 네 다 틀 네 다 틀
# 정답:  ['연령', '지역'] ,예측:  ['지역']
#
# 문장:  무슬림 남성 들 이 결혼 못 하는 노처녀 메 갈 돼지 들 을 노려서 한국 에 정착 할 수도 있다 .
# 정답:  ['여성/가족', '인종/국적'] ,예측:  ['여성/가족', '종교']
#
# 문장:  서 양 백마 들 이오 면 = 착한 다문화 동남아 똥송년 들 오면 = 나쁜 다문화
# 정답:  ['여성/가족', '인종/국적'] ,예측:  ['인종/국적']
#
# 문장:  어디서 숙명 드립 이야 씨발 한명숙 같은 씨벌년 이 한국 와 서 출세 했으면 가만히 나 있던가 아무튼 똥 남아 새끼 들 미개한 겁 알아줘 야함
# 정답:  ['인종/국적', '개인지칭'] ,예측:  ['인종/국적']
#
# 문장:  어차피 홍어 새끼 들 조상 이 똥 남아 일텐데
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '지역']
#
# 문장:  내 가 볼땐 틀무새 나 좆족무새 똑같음 서로 허공 만 때리면서 내 가 더 타 격감 좋았네 니 가 쳐 발렸네 거리 고 있음 ㅋㅋㅋㅋ 병신 새끼 들
# 정답:  ['인종/국적', '연령'] ,예측:  ['인종/국적']
#
# 문장:  천조국 대통령 이 성경책 에 손 얹고 선서 하는 거 보면 존나 멋있고 감동 적 인데 김치 맨 들 이 하면 그저 똥송
# 정답:  ['인종/국적', '개인지칭'] ,예측:  ['인종/국적']
#
# 문장:  착 짱 죽 짱 착 조 죽 조 착홍죽홍
# 정답:  ['인종/국적', '지역'] ,예측:  ['인종/국적']
#
# 문장:  무슬림 좆 들 은 뱃속 에 있을 때 부터 갈았어야 했노 조팔
# 정답:  ['인종/국적', '종교'] ,예측:  ['인종/국적']
#
# 문장:  참 저 한마디 했다고 10년 이 가까이 강호순 유영철 보다 더 가열 차게 까이는게 말 이 되노 소 추 한 냄 국 토나온다 이기 야
# 정답:  ['남성', '개인지칭'] ,예측:  ['남성']
#
# 문장:  대 구 게이 는 일베 글 쓰지 마라 IP 타고 우한 폐렴 전파 된다
# 정답:  ['인종/국적', '지역'] ,예측:  ['인종/국적', '개인지칭']
#
# 문장:  위 에 벌써 예수 쟁이 들 몰려와서 변명 늘어놓는거 보소 ㅋㅋㅋ 저러니까 개독 소리 듣는건데 지 들만 모름 저 새끼 들 공룡 이고 뭐 고 전부 주작 이라고 생각 함 그냥 정신 병자 들
# 정답:  ['종교', '기타 혐오'] ,예측:  ['기타 혐오']
#
# 문장:  민주화 운동 하는거니까 냅 둬라 . 기사도 내지마라 . 보기 싫다 그 짝 기사 는 ㅉ
# 정답:  ['지역'] ,예측:  ['여성/가족', '지역']
#
# 문장:  그러면 뭐 가 아쉬워서 탈북 했냐 아주 쳐 입 만 열면 전라도 마냥 구라 가 자동 으로 튀어 쳐나와
# 정답:  ['인종/국적', '지역'] ,예측:  ['인종/국적']
#
# 문장:  개슬람 새끼 들 좆 미개
# 정답:  ['종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  개독 새끼 들 똥꼬 충 막는다 어쩐 다 지랄 떨더면 성과 도 없음
# 정답:  ['종교'] ,예측:  ['성소수자', '종교']
#
# 문장:  이 게 다 한 남충 이 똥 남아 년 들 사와서 그런거아니 예 욧 !!!
# 정답:  ['여성/가족', '남성', '인종/국적'] ,예측:  ['여성/가족', '인종/국적']
#
# 문장:  쉬벌 좀비 영화 찍지말고 무슬림 으로 대체 해라 현실 성 있고 더 무섭다
# 정답:  ['인종/국적', '종교'] ,예측:  ['종교']
#
# 문장:  급 식충이 더 잘 못 했는데 ? 저런거 다 감안 하고 댓글 에 욕 한 거 아니냐 ? 센 징 들 은 쳐 맞아야 말 듣는다는걸 몸소 실천 하고 있구만 악어 키우는 놈 이 ㅋㅋ
# 정답:  ['인종/국적', '연령'] ,예측:  ['연령', '개인지칭']
#
# 문장:  우리나라 도 미개한 파퀴 필리 피노 조선족 이슬람 새 키 들 넘친다
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '종교']
#
# 문장:  유충 낙태 는 에티켓 봊 나 맞는말이노 워 추다 이기
# 정답:  ['남성', '연령'] ,예측:  ['남성']
#
# 문장:  툭 까놓고 말 해 한국 에서 할랄 푸드 이슬람 기 도실 이 늘어야 할 이유 가 없지 않나
# 정답:  ['인종/국적', '종교'] ,예측:  ['종교']
#
# 문장:  틀 딱 들 특징 자기 들 논리 에 안 맞으면 상대 가 고향이 중국 으로 바뀜 ㄹㅇ
# 정답:  ['연령'] ,예측:  ['여성/가족', '연령']
#
# 문장:  보 빨오지네 커피 먹는거랑 여자 랑 무슨 상관 이냐 ? 여자 들 이 허영 심 가득 차서 커피 오지 게 처 먹는건 알 지만
# 정답:  ['여성/가족', '개인지칭'] ,예측:  ['여성/가족', '기타 혐오']
#
# 문장:  샤오미 쓸 듯 춘장 보지 년 ;
# 정답:  ['여성/가족', '인종/국적'] ,예측:  ['여성/가족']
#
# 문장:  단룡 인 >>>>>>>>>>>>>>>>>>> 중국인 노동자 >>>>>>>>>>>>>>>>>>> 조선인
# 정답:  ['인종/국적', '기타 혐오'] ,예측:  ['인종/국적']
#
# 문장:  2030 한테 틀 딱 몰이 하 는 40 대전 라도 스냅백 틀 딱 병신 들
# 정답:  ['연령', '지역'] ,예측:  ['연령']
#
# 문장:  윤석렬 은 더 패 미인데 개 무식한 새끼 . 그 주둥이 다물라
# 정답:  ['악플/욕설', '개인지칭'] ,예측:  ['여성/가족', '개인지칭']
#
# 문장:  의사 들 수가 목사 들 수 절반 만 되어도 의료 공백 은 없을텐데
# 정답:  ['종교', '기타 혐오'] ,예측:  ['종교']
#
# 문장:  사람 을 키워내는게 아니라 애 새끼 를 정신 적 앉은뱅이 로 만들고 있음 븅신 맘충 새끼 들
# 정답:  ['여성/가족', '기타 혐오'] ,예측:  ['여성/가족']
#
# 문장:  무슬림 과 문슬림 은 ㄴ 하나 차이 다 그 해악 도 비 스무 리하 다
# 정답:  ['종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  양키 들 다문화 실패한거 보고 왜 따라하는지 이해 불가 ....
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '개인지칭']
#
# 문장:  원래 부터 웜 은 친 똥꼬 성향 이었노 66 한남 끼리 결혼 하면 집 이 두 채 !! 99
# 정답:  ['남성', '성소수자'] ,예측:  ['남성']
#
# 문장:  ㅇㅇ 좌빨 + 기독 은 무적 조합 이다
# 정답:  ['종교', '기타 혐오'] ,예측:  ['기타 혐오', '개인지칭']
#
# 문장:  페미 하는 애 들 특 못 생기고 바퀴벌레 같이 생김
# 정답:  ['여성/가족'] ,예측:  ['여성/가족', '인종/국적']
#
# 문장:  우리나라 평생 총기 허용 되면 안된다 . 탈북자 랑 전라도 조선족 새끼 들 존나 총 맞을듯 . 대가리 구멍 존나 게 낼듯 .. 그거 아니라도 죽창 으로 ㅆㅂ
# 정답:  ['인종/국적', '지역'] ,예측:  ['인종/국적']
#
# 문장:  군대 식단 에서 돼지고기 빠짐 ㅋㅋ 소고기 랑 닭고기 도 할랄 고기 로 바뀜 ㅋㅋㅋㅋ
# 정답:  ['인종/국적', '종교'] ,예측:  ['인종/국적', '개인지칭']
#
# 문장:  ㄹㅇ 개좃같 은 페미 민국 진짜 요즘 좌좀 달창 분탕년 들 남초 에 오지 게 풀었 더 만 애국 하면서 노예 처럼 살아가라고 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 정답:  ['여성/가족'] ,예측:  ['여성/가족', '개인지칭']
#
# 문장:  쓰까 젠더 무새 젠 신 병자 들 싹 다모아 서 원자폭탄 후 장 에 꼽 고 재기 시켜야 되는 쀼젤 이노 저 것 들 모 여서 젠더 못 잃어 하는 꼴 보면 어이 가 마포 가 뿟노
# 정답:  ['성소수자', '기타 혐오'] ,예측:  ['성소수자']
#
# 문장:  맞노 허 벌후 장 뚫리면서 커야 조신 해지노
# 정답:  ['남성', '성소수자'] ,예측:  ['남성']
#
# 문장:  갑질 장군 박찬주 영 입하 고 .. 교 안이 는 박광훈 사이비 목사 놈 하고 절친 이고 .. 진정 이 답 이 없는 틀 딱 당 .. ㅜ
# 정답:  ['연령', '개인지칭'] ,예측:  ['연령', '종교']
#
# 문장:  외국인 들 에게 퍼주 는 수준 = 무현 머 중정부 시절 정일 이 한테 무료 로 쌀퍼주고 돈퍼줬던 수준
# 정답:  ['인종/국적', '개인지칭'] ,예측:  ['인종/국적']
#
# 문장:  한국 에서도 좆 같은 파키스탄 , 방글라데시 같은 개슬람 놈 들 다 몰아내야 한다 . 잠재 적 IS 개슬람 원리 주의 테러 분자 새끼 들
# 정답:  ['종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  캬 .. 저렇게 예쁘고 몸 빵빵 헌 똥꼬 도 칼 맞는데 한남 똥꼬 충 들 은 걍 싹 화형식 거행 각 이노 ...
# 정답:  ['남성', '성소수자'] ,예측:  ['남성']
#
# 문장:  여성부 와 페미 의 이 기적 인 결과물 아니겠냐 이제 급식 들 도 세뇌 완료 됐고 갈수록 여자 들 갑질 은 심해질거고 한남 으로 사는건 더 힘들어질 거 다
# 정답:  ['여성/가족'] ,예측:  ['여성/가족', '연령']
#
# 문장:  막 짤 존나 웃기노 개슬람 새끼 들 통수 지리구여 홍어 새끼 마냥 통수쳐 버리노
# 정답:  ['지역', '종교'] ,예측:  ['지역']
#
# 문장:  지구 오물 짱개 무슬림 을 인간취 급하지말라
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '종교']
#
# 문장:  스시 녀 ㅅㅅ 마스터 노 ?
# 정답:  ['여성/가족', '인종/국적'] ,예측:  ['여성/가족']
#
# 문장:  이 거 봐 다 한 패 야 검찰 개독 미 통 나쁜 놈
# 정답:  ['종교', '기타 혐오'] ,예측:  ['종교']
#
# 문장:  칭기즈칸 성 님 은 개슬람 새끼 들 한 톨 남김없이 조졌는데 칭기즈칸 후손 인 우리 는 왜 그렇게 못 하냐
# 정답:  ['인종/국적', '종교'] ,예측:  ['종교']
#
# 문장:  국경 을 봉쇄 하고 한 녀 들 을 몽둥이 로 팬 다음 에 결혼 못 한 혐오 스러운 일게이 들 한테 무상보 급 해줘야 된다 그 래야 나라 가 바로 선다
# 정답:  ['여성/가족', '기타 혐오'] ,예측:  ['여성/가족']
#
# 문장:  근데 무슬림 인식 이 원래 안좋잖아 한국 에선 그냥 무슬림 보면 신기하다에서 끝 인데 미국 에선 무슬림 이 가방 던지면 폭탄 인 줄알 고 존나 뛰 더 만
# 정답:  ['종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  자지 들 끼리 좆 비비 다 유충 까고 셋 이 손잡고 재기 하면 되겠노 ^ 좆 ^
# 정답:  ['남성', '성소수자', '연령'] ,예측:  ['남성']
#
# 문장:  시발 개슬람대 짱깨 전쟁 하 면 미국 이랑 한국 은 각각 누구 편 들 게 될까 ??
# 정답:  ['인종/국적', '종교'] ,예측:  ['인종/국적']
#
# 문장:  때린건 100% 잘못 인데 이렇게 들어 보 니까 베트콩 년도 개 썅년 이네 . 남자 구속 되면 튈라고 기획 한 듯
# 정답:  ['여성/가족', '인종/국적'] ,예측:  ['여성/가족']
#
# 문장:  으으 씨발 외국 에서 한국인 = 똥 남아 인종 으로 알듯
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '개인지칭']
#
# 문장:  페미 하는 주제 에 한남 하네 ~
# 정답:  ['여성/가족', '남성'] ,예측:  ['남성']
#
# 문장:  씨발 개새끼 . 달창 들 ㆍ 짱깨 들 ㆍ 조선족 들 ㆍ 버러지 들 ㆍ 전라 인들 . 학살 해야 한다
# 정답:  ['인종/국적', '지역'] ,예측:  ['인종/국적']
#
# 문장:  미친 년 은 정상 적 인 여자 가 까야 됨여명숙 누나 좋아하는 eu
# 정답:  ['여성/가족', '개인지칭'] ,예측:  ['여성/가족']
#
# 문장:  홍어 , 개독 , 한괴레 트리플 그랜드 슬램하면쥬댕이 가 저렇게 저 질 스러워 짐 ??
# 정답:  ['지역', '종교', '기타 혐오'] ,예측:  ['지역']
#
# 문장:  이 년 통찰 력 지리노 ㅋㅋㅋㅋㅋ 스시 좆 이랑 혐애 했었는데 ㄹㅇ 다 똑같노 ㅋㅋ 반면 한 남충 들 의 음침하고 보기 만 해도 기분 다운 되는 식민지 남성성 잘 집어 냈노 ㅋㅋㅋㅋ 스시 남 이 한 남충 한번 더 쓸어주면 좋겠노 ㅋㅋㅋ
# 정답:  ['남성', '인종/국적'] ,예측:  ['남성']
#
# 문장:  헌금 !!!!!! 하면 제 일 사랑 교회 전광훈 목사 와 그 를 따르는 목사 들 을 따라 갈수 가 없지요 ㅋㅋㅋ
# 정답:  ['종교', '개인지칭'] ,예측:  ['종교']
#
# 문장:  요즘 급식 충 들 막 이기 이기 거리 면서 다니는 새끼 들 많던데 괜찮을거 같기 도하 다 ㅋㅋㅋㅋ
# 정답:  ['연령'] ,예측:  ['남성', '연령']
#
# 문장:  ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 시발 그럼 김치 년 90 프로 가 레즈 노 ?
# 정답:  ['여성/가족', '성소수자'] ,예측:  ['여성/가족']
#
# 문장:  진주 출신 인데 경상도 아저씨 들 정직 한편 인데 말 많고 오지랖 뒤짐 지나 잘 살 지 서울 올라오니 아저씨 들 조용해서 좋은데 길 돌아감 근데 요즘 엔 네 비 키 고 가니 그런 일 거의 없더라
# 정답:  ['지역'] ,예측:  ['지역', '개인지칭']
#
# 문장:  개독교 가는 목적 이 섹스 or 인맥 및 비즈니스 용 아니고 진짜 믿는 새끼 들 은 걸러 라 대화 하다 보면 정신병 자 가 따로 없음
# 정답:  ['종교', '기타 혐오'] ,예측:  ['종교']
#
# 문장:  공산주의 문화 막시즘 난민 동성애 페미니즘 공산당 의 자 국민 몰살 전략
# 정답:  ['여성/가족', '성소수자', '인종/국적', '기타 혐오'] ,예측:  ['여성/가족', '성소수자']
#
# 문장:  촌놈 새끼 들 나이 는 나이 대로 쳐 먹어놓고 똥 남아 병신년 사먹지 좀 마라
# 정답:  ['인종/국적', '지역'] ,예측:  ['여성/가족', '지역']
#
# 문장:  포탄 날라가다 바람 불어 서 즌라도 로 가면 좋겠다 그것 도 전남 에 있는 ' 슨상 그라드 ' 로
# 정답:  ['지역', '개인지칭'] ,예측:  ['지역']
#
# 문장:  한국 에도 이슬람 을 능가 하는 좌슬람 새끼 들 이 곧 저런 짓 하고 다닐거다
# 정답:  ['종교', '기타 혐오'] ,예측:  ['인종/국적', '종교']
#
# 문장:  본래 희귀 성씨 가진 사람 들 이 족보 에 시조 가 중국 이나 어디 다른 나라 에서 귀화 한 걸 로 돼있어서 이민 정책 에 관대한 편 .
# 정답:  ['인종/국적', '개인지칭'] ,예측:  ['인종/국적']
#
# 문장:  예쁘고 잘난 여자 가 ㅆㅎㅌㅊ 냄져 한테 후려쳐져서 사는 현실 보고 도 그런 말 이 나오냐고 해봐라 지금 현실 이 그렇게 도덕 못 잃고 코르셋 조여 살아서 얻는 결과 가 결국 루저 한 남충 이라 는걸 깨 달아야 된다 . 그 말 조차 안통 하 면 ㄹㅇ 지 맘 대로 살라 하고 상종 말라 이기 야
# 정답:  ['남성'] ,예측:  ['여성/가족', '남성']
#
# 문장:  남자 들 은 예전 과 같은데 진선미 개 씹 창년 당선 된거 보면 이나라 여성 들 이 그냥 보지 달린 아메바 임
# 정답:  ['여성/가족', '개인지칭'] ,예측:  ['여성/가족']
#
# 문장:  개슬람 새끼 들 좀 추방 좀
# 정답:  ['종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  할 짓거리 없이 책상 머리 틀어박혀 하는거라곤 피해망상 뿐인 페미 쿵쾅 이 기레기 들 싹 다 잡아다 군대 훈련소 보내 남자 똑같이 훈련 하게 하면 하루 도 못 가 눈물 찔 찔 짜며 살려주세요 다신 망상 안 할께요 할텐데
# 정답:  ['여성/가족', '기타 혐오'] ,예측:  ['여성/가족']
#
# 문장:  저런 극우 가 있어야 외국인 들 도 남 에 나라 와 서 함부로 찍 소리 도 못 하지이건 뭐 더 큰소리 치고 다니고 자빠졌으니 ... 무슨 태극기 흔드는 영감 탱 이 들보 고 극우 래 ㅋㅋ
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '개인지칭']
#
# 문장:  편 가르 기는 홍어 , 좌빨 의 종특 이지 오세훈 당선 후 일베 에 조직 적 , 반복 적 으로 이런 글 올라오는 목적 은 단 하나 지
# 정답:  ['지역', '기타 혐오'] ,예측:  ['지역']
#
# 문장:  국민의당 - 동교동계 김머중 따까 리 + 간 철수 연합 더 민주 - 노뽕 홍어
# 정답:  ['지역', '개인지칭'] ,예측:  ['지역']
#
# 문장:  페미 20 대여 와 스윗 남 40 대의 환 장 의 콜라보 . 우연 인지 몰라도 민주당 지지율 높은 세대
# 정답:  ['여성/가족', '연령'] ,예측:  ['여성/가족', '개인지칭']
#
# 문장:  온 가족 들 이 정신 병자 들 이네
# 정답:  ['기타 혐오'] ,예측:  ['성소수자', '기타 혐오']
#
# 문장:  짱꼴라 기레기 야 중국 발 국적 표시 말고 국내 거주 중 인 짱 께 싯기 들 국적 표시 도 해야지 ~~ 청와대 사이트 도 문재인 탄핵 반대 청원 동의 한 새끼 들 국적 을 밝히라고 본질 흐리지 말고
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '개인지칭']
#
# 문장:  나 한테 이슬람 좆 들 칼푹찍 할 권리 를 달라 이기 조 팔 것 들
# 정답:  ['남성', '인종/국적', '종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  원 글 잘 읽어 보면 중 남충 이 쓴거네 ㅋㅋㅋ 여기 양 남도 먹지 말라는데 무슨 남부 를 찾노
# 정답:  ['남성', '인종/국적'] ,예측:  ['남성']
#
# 문장:  준석 아 힘내라 ! 페미 , 페미 호소 인 은 정상인 간 이 아니다 . 인간 처럼 여기 지 마라
# 정답:  ['여성/가족', '개인지칭'] ,예측:  ['여성/가족']
#
# 문장:  이방 카 패러디 한 영상 봐야겠다 시 부레 ... ㄹㅇ 이방 카세 절 예 존예 보스 임 퇴물 페미 된 블랙위도우 년 이 이방 카 코스프레 하고 비꼬는데 존나 눈물 겹더 라 ㅋㅋ
# 정답:  ['여성/가족', '개인지칭'] ,예측:  ['여성/가족']
#
# 문장:  재앙 이 도 대가리 좆창 나서 삼수 해서 꾸역꾸역 경희대 가는데 지 잡 대 앱생 인생 들 은 뭐란말이노 이기
# 정답:  ['기타 혐오', '개인지칭'] ,예측:  ['성소수자', '기타 혐오']
#
# 문장:  파퀴 벌레 새끼 들 남자 만 수출 하고 여자 는 꽁꽁 숨겨 두고 개새끼 들 니 들 도 여자 좀 수출 해 개 씨발 새끼 들 아
# 정답:  ['인종/국적'] ,예측:  ['여성/가족', '인종/국적']
#
# 문장:  조팔 쓰까 들 얘기 들을 때 마다 앵 나 스트레스 받노 글 쓴련 한테 완전 동감 한다 쓰 까는 이제 여자 한테 도움 이 안된다 말 만 페미 지 그냥 똥꼬 충 인권 운동 가나 마찬가지 임
# 정답:  ['성소수자'] ,예측:  ['여성/가족', '성소수자']
#
# 문장:  영자 가 틀린 말 한 거 없는거 맞음 한국 사람 들 이 좆족 , 짱개 라고 하는건 짱 개국 탈출 해서 한국 이나 그 외 지역 에 기생 하면서 똥물 퍼뜨리 는 새끼 들 은 얘기 하 는 거지 아 화교 새끼 들 포함
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '개인지칭']
#
# 문장:  신천지 들 이 계획 이 다 있구나 동성애자 들 이랑 연합 해서 이런 식 으로 몰구 가보려구 ? ㅋㅋ
# 정답:  ['성소수자', '종교'] ,예측:  ['성소수자']
#
# 문장:  이자스민 정도 면 주 절 먹
# 정답:  ['여성/가족', '인종/국적', '개인지칭'] ,예측:  ['연령', '개인지칭']
#
# 문장:  똥 양 남 혼자 나 똥 양 남 들 끼리 는 돈 아무리 내도 클럽 입장 도 안 됨 . 보지 데려가야 입장 됨 ㅋㅋ
# 정답:  ['남성', '인종/국적'] ,예측:  ['여성/가족', '인종/국적']
#
# 문장:  88년 에 세례 받은 천주교 신 자임 . 세례명 은 다니엘 . 교황 개새끼
# 정답:  ['종교', '개인지칭'] ,예측:  ['종교']
#
# 문장:  역시 좌파 는 돈 이 된다 전라도 모임 에 고문 까지 ㅋㅋ
# 정답:  ['지역'] ,예측:  ['지역', '개인지칭']
#
# 문장:  미세먼지 도 좆 같은데 폐병 걸리면 문 재앙 개새끼 랑 짱깨 들 몇 마리 데리 고 간다 진심
# 정답:  ['인종/국적', '개인지칭'] ,예측:  ['인종/국적']
#
# 문장:  개슬람 = 전라도 반박 시 홍어 인정
# 정답:  ['지역', '종교'] ,예측:  ['지역']
#
# 문장:  무슬림 여성 테러범 들 중 에 니캅 안 쓴 여자 가 단 한 명도 없었다 . 쫒 겨나도 싸고 추방 당해도 싸다 .
# 정답:  ['여성/가족', '종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  이슬람 다른건 몰라도 피 싸개 들 때려 잡는건 마음 에 든다
# 정답:  ['여성/가족'] ,예측:  ['여성/가족', '종교']
#
# 문장:  솔직히 한국 에서 태어나서 박정희 욕 하는 새끼 는 간첩 이 거나 전라도 새끼 임 ㄹㅇㅍㅌ ㅂㅂㅂㄱ
# 정답:  ['지역', '개인지칭'] ,예측:  ['지역']
#
# 문장:  신천지 교회 이제 는 이슬람 까지 우리나라 종교 에게보다 더 엄격하게 관리 해야 한다고 생각 합니다 미우나 고우나 내 국 인 이야 뭐 야단 칠거 치고 치료 하고 조심 시킨 다쳐도 외국인 은 민폐 끼치면 출국 시키는것이 당연하다고 봅니다
# 정답:  ['인종/국적', '종교'] ,예측:  ['종교']
#
# 문장:  전라도 홍어 들 이랑 좆족 새끼 들 은 말살 을 시켜야지
# 정답:  ['인종/국적', '지역'] ,예측:  ['지역']
#
# 문장:  우 리아 라 유학생 애 들 이 제일 싫어하는게 중국 애 들 일텐데 ㅋㅋ 여자애 가 중국 남자 가 좋다고 ??
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '개인지칭']
#
# 문장:  좌파 새끼 들 툭하면 일제 강점 기 때 조선인 은 2등 시민 이런 개 소리 하는데 자금 조선인 은 중국인 1 순위 홍어 2 순위 를 차지 해 버려서 사실 상 3~4 류시민 임
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '지역']
#
# 문장:  와 얘 네 믿고 거르 는 쌍 도 남자 모르나 봄 .
# 정답:  ['남성', '지역'] ,예측:  ['지역']
#
# 문장:  홍어 다문화 가 날뛰니 이제 는 필통 까지 분탕 질하노
# 정답:  ['인종/국적', '지역'] ,예측:  ['지역']
#
# 문장:  지금 이나라 에 있는 파퀴 방글 라 무슬림 새끼 들 즉각 추방 하 지 않는다면 똑같이 된다 동남아 거지 새끼 조선족 도 추방 시켜 야한다
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '종교']
#
# 문장:  킴 카다 시안 이 씨발 년 하는 짓은 페미 앞 잽이같이 생겼는데 아니였냐 ?
# 정답:  ['여성/가족', '개인지칭'] ,예측:  ['여성/가족']
#
# 문장:  한남 아웃 !! 잠재 적 성범죄 !! 분명 까 보면 고향이 쌍 도일 가능성 이 높음
# 정답:  ['남성', '지역'] ,예측:  ['남성']
#
# 문장:  ㅋㅋㅋㅋ 좆 본 몇 년 살았었는데 노무 딱 맞는 말 이노 전 스시 남충 도 말 도 안 해도 때 마다 비싼 악세사리 나 가방 갖다 바쳤노 ㅇㅇ 한 남충 들 좆 그 지라 중요한 날 에도 큰 맘 먹고 O . S . T 사주고 생색 내지 않노 ㅋㅋㅋㅋ
# 정답:  ['남성', '인종/국적'] ,예측:  ['남성']
#
# 문장:  ㅋㅋㅋㅋ 오히려 애매하게 작은게 바늘 처럼 찔러 대면 아프노 아 물론 한남 좆 은 마이크로 사이즈 라 그것 도 해당 이 안된다 이 니야
# 정답:  ['남성'] ,예측:  ['남성', '기타 혐오']
#
# 문장:  여자 의 적은 여자 다 = 임순영 좌파
# 정답:  ['여성/가족', '기타 혐오', '개인지칭'] ,예측:  ['여성/가족']
#
# 문장:  미국 에서 짱 깨란 누명 쓰고 처 맞고 댕기 는 데 뚜껑 열 리지 미국 뿐이겠노 동양인 껍데기 쓰고 여행 다니면 짱깨 누명 쓰고 온갖 핍박 받을게 뻔한데 외국 에 환장한 김치 년 들 대가리 다 깨지지
# 정답:  ['여성/가족', '인종/국적'] ,예측:  ['인종/국적']
#
# 문장:  게임 사 잘 했다 . 언론 들 과 페미 깡페 들 준 동하 네 기생충 들
# 정답:  ['여성/가족', '기타 혐오'] ,예측:  ['여성/가족']
#
# 문장:  키 야 사스 가 갓 스시 녀
# 정답:  ['여성/가족', '인종/국적'] ,예측:  ['인종/국적']
#
# 문장:  군대 가니까 최군 보단 낫 네 ㅋㅋ
# 정답:  ['악플/욕설', '개인지칭'] ,예측:  ['악플/욕설']
#
# 문장:  한국 패 미 = 고 유정 수준 ㅋㅋㅋ
# 정답:  ['여성/가족', '개인지칭'] ,예측:  ['여성/가족']
#
# 문장:  옥주현 이 방송 가에서 홍어 카르텔 에 얼마나 괴롭힘 당했겠냐 안 봐도 비디오
# 정답:  ['지역', '개인지칭'] ,예측:  ['지역']
#
# 문장:  좌빨 종북 주사파 달창 대 개문 김정은 애완견 들 조 민 표창장 은 어디서 나온거야 유시민 은 동양대 총장 한 데 전화 는 왜 한거야 중국 가서 사드 보복 하 라 구 고자질 은 누가 한거야 비리 들어나면 메신저 공격 하는 생 양 아치 좌빨 종북 주사파 달창 대 개문 김정은 애완견 들
# 정답:  ['기타 혐오', '개인지칭'] ,예측:  ['연령', '개인지칭']
#
# 문장:  암 홍어 시발 ㅋㅋ
# 정답:  ['여성/가족', '지역'] ,예측:  ['지역']
#
# 문장:  비엘 사실 상 레즈 아니노 ? 비엘 나오는 자지 처럼 생각 하는 자지 없음 . 다 보지 생각 이다 .
# 정답:  ['여성/가족', '남성'] ,예측:  ['남성']
#
# 문장:  개독 을 홍어 만큼 싫어하는게 좆베 아니노 ? 이중성 클래스 ;;
# 정답:  ['지역', '종교'] ,예측:  ['지역']
#
# 문장:  벨기에 가 지역 감정 도 심하고 언어 도 여러 개 쓰고 ... 뭔가 짬뽕 많이 된 유럽 국가 . 근데 이슬람 까지 합세 한 걸 보니 최종 승자 는 이슬람 이 되겠네
# 정답:  ['인종/국적', '종교'] ,예측:  ['종교']
#
# 문장:  페미니즘 은 걍 정신병 자 들임 ㅋㅋ
# 정답:  ['여성/가족', '기타 혐오'] ,예측:  ['여성/가족']
#
# 문장:  통구이 들 특징 : 지 들 까이는 떡밥 이면 급하게 화제 전환 마 ! 이 게 쌍 도 남자 아이 가
# 정답:  ['지역'] ,예측:  ['남성', '지역']
#
# 문장:  동성애 조장 하여 에이즈 양산 하고 국민 들 의 법 감정 무시 하는 악법 절대 반대 합니다
# 정답:  ['성소수자', '기타 혐오'] ,예측:  ['성소수자']
#
# 문장:  개독 개 독해도 더러운 똥꼬 충 새끼 들 처단 에는 개독 만 한 게 없다
# 정답:  ['인종/국적', '종교'] ,예측:  ['성소수자', '종교']
#
# 문장:  동남아 , 파키스탄 이런 류 보단 나을지도 모르지
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '지역']
#
# 문장:  그래도 이제 나마 대 깨문 탈출 한 거 보면 맘충 중 에서도 그나마 지능 이 높은 편 에 속 하는군 .
# 정답:  ['여성/가족', '기타 혐오'] ,예측:  ['여성/가족']
#
# 문장:  개독 vs 라도 선택 은 ?
# 정답:  ['지역', '종교'] ,예측:  ['종교']
#
# 문장:  돈 고 들 사이 에서 6일 스 9 스타일 유행 하는거 꼭 봐야겠노 . 일틱훈냄 찾아요 . 6 티나 는 탑 9 6 티나 는 바텀 9 안 받아요 . 이 꼴 꼭 봐야겠노 . 그리고 모든 냄 저 는 사실 잠죄 적 돈 고충 이란 사실 을 다 퍼트 리 면 더 좋겠노
# 정답:  ['남성', '성소수자'] ,예측:  ['성소수자']
#
# 문장:  맘충 = 진상 거지 년 이 애 낳은 것
# 정답:  ['여성/가족', '기타 혐오'] ,예측:  ['여성/가족']
#
# 문장:  나치독일 때 도 동성애자 들 그렇게 죽여 댔는데 그때 도 동성애자 있었음 ㅋㅋㅋ 이 게 막을수 없다는거 임 ㅇㅇㅇ
# 정답:  ['성소수자'] ,예측:  ['성소수자', '기타 혐오']
#
# 문장:  한국 새끼 들 대학가 려고 쌔빠지 게 공부 하는거 못 보나 지 들 나라 에선 제대로 된 대학 이나 있는지 걱정 이네 똥 남아 시 키 들 ㅋㅋ
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '개인지칭']
#
# 문장:  무슬림 개새끼 들 그냥 중동 에 모 여서 살길 . 이 개새끼 들 은 짱깨 와 다르게 말 도 안통 하 는 존재 들 이다 . 중동 에 가둬놓고 상종 안하는게 답 .
# 정답:  ['인종/국적'] ,예측:  ['인종/국적', '종교']
#
# 문장:  틀 딱 + 빨깽 이 = 문 재앙
# 정답:  ['연령', '기타 혐오', '개인지칭'] ,예측:  ['연령', '개인지칭']
#
# 문장:  문 슬림 들 도 그 들 의 본국 인 북한 과 중국 으로 추방 시키자
# 정답:  ['종교'] ,예측:  ['인종/국적', '종교']
#
# 문장:  조팔 그럼 50 매 에 구천원 짜리 노트 쓰는 난 뭐 메 가 김치 녀 냐 한남 아 ?
# 정답:  ['여성/가족', '남성'] ,예측:  ['여성/가족']
